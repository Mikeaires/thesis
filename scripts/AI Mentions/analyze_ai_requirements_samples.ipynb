# %% [markdown]
# # AI Requirements — Random Samples
# This notebook samples full job texts with their AI requirement classification, detected keywords, and year.

# %%
from pathlib import Path
import json, bz2, re, random
import pandas as pd
from collections import defaultdict

def find_root(start: Path) -> Path:
    for p in [start] + list(start.parents):
        if (p / 'Results Datasets').exists():
            return p
    return start

ROOT = find_root(Path.cwd())
REQ_PATH = ROOT / 'Results Datasets' / 'ai_mentions' / 'ai_job_requirements_simple.json'
MATCH_PATH = ROOT / 'Results Datasets' / 'ai_mentions' / 'ai_keyword_matches_fulltext.json'
TEXT_DIR = ROOT / 'Base Dataset' / 'Data' / '699_SJMM_Data_TextualData_v10.0' / 'sjmm_suf_ad_texts'

print('Reading requirements:', REQ_PATH)
req_data = json.loads(REQ_PATH.read_text(encoding='utf-8')) if REQ_PATH.exists() else {}
match_data = json.loads(MATCH_PATH.read_text(encoding='utf-8')) if MATCH_PATH.exists() else {}
len(req_data), len(match_data)
# Out:
# Reading requirements: /Users/miguel/Documents/Master Thesis/Thesis/Results Datasets/ai_mentions/ai_job_requirements_simple.json
# (15, 15)

# %%
# Build per-ad keywords and flattened DF
ad_keywords = defaultdict(set)
for year, ads in match_data.items():
    for ad_id, matches in ads.items():
        for m in matches:
            kw = (m.get('keyword') or '').strip()
            if kw:
                ad_keywords[ad_id].add(kw)

rows = []
for year, ads in req_data.items():
    for ad_id, res in ads.items():
        rows.append({
            'year': int(year),
            'ad_id': ad_id,
            'ai_requirement': bool(res.get('ai_requirement', False)),
            'reason': (res.get('reason') or ''),
            'keywords': sorted(ad_keywords.get(ad_id, [])),
        })
df = pd.DataFrame(rows)
df.shape
# Out:
# (614, 5)

# %%
# Utilities
def extract_year_from_ad(ad_id: str):
    for part in ad_id.split('-'):
        if part.isdigit() and 1900 <= int(part) <= 2100:
            return int(part)
    return None

def load_ad_text(ad_id: str, year_hint: int | None = None):
    year = year_hint or extract_year_from_ad(ad_id)
    if year is None:
        return ''
    p = TEXT_DIR / f'ads_sjmm_{year}.jsonl.bz2'
    if not p.exists():
        return ''
    with bz2.open(p, 'rt', encoding='utf-8') as fh:
        for line in fh:
            try:
                obj = json.loads(line)
            except Exception:
                continue
            if obj.get('adve_iden_adve') == ad_id:
                txt = obj.get('adve_text_adve') or ''
                return txt if isinstance(txt, str) else ''
    return ''

def highlight(text: str, keywords: list[str]):
    out = text
    for kw in sorted(set(keywords), key=len, reverse=True):
        if not kw:
            continue
        try:
            pat = re.compile(re.escape(kw), re.IGNORECASE)
            out = pat.sub(lambda m: '<<' + m.group(0) + '>>', out)
        except Exception:
            pass
    return out

# %% [markdown]
# ## Filters and sampling
# Set the filters below and run the sampling cell to display random ads with their classification, year, keywords and a text preview.

# %%
# Filter parameters
FILTER_YEAR = None          # e.g., 2022 or None
REQUIREMENT = None          # True / False / None
TARGET_KEYWORDS = []        # e.g., ['LLM','ChatGPT','machine learning']
MATCH_MODE = 'any'          # 'any' or 'all'
N_SAMPLES = 10              # number of random ads to display
PREVIEW_CHARS = 1000        # text preview length

q = df.copy()
if FILTER_YEAR is not None:
    q = q[q['year'] == int(FILTER_YEAR)]
if REQUIREMENT is not None:
    q = q[q['ai_requirement'] == bool(REQUIREMENT)]
if TARGET_KEYWORDS:
    tk = [t.lower() for t in TARGET_KEYWORDS]
    def has_kw(ks):
        s = set(k.lower() for k in ks)
        return (any(k in s for k in tk) if MATCH_MODE=='any' else all(k in s for k in tk))
    q = q[q['keywords'].apply(has_kw)]

print('Filtered rows:', len(q))
sample = q.sample(min(N_SAMPLES, len(q)), random_state=None) if len(q) else q
sample.reset_index(drop=True, inplace=True)
sample[['year','ad_id','ai_requirement','reason','keywords']].head(N_SAMPLES)
# Out:
# Filtered rows: 614
#    year                                    ad_id  ai_requirement  \
# 0  2023  sjmm_suf-2-05-2023-03-05886-1-000248901            True
# 1  2023  sjmm_suf-3-01-2023-03-09003-1-045295809           False
# 2  2021  sjmm_suf-3-01-2021-03-09001-1-027487798            True
# 3  2013  sjmm_suf-3-01-2013-03-09010-0-000002206           False
# 4  2021  sjmm_suf-3-01-2021-03-09003-1-027426622           False
# 5  2011  sjmm_suf-2-01-2011-03-00986-0-000000190           False
# 6  2017  sjmm_suf-1-01-2017-03-03112-0-000000373            True
# 7  2024  sjmm_suf-2-05-2024-03-05336-1-000371875            True
# 8  2020  sjmm_suf-3-01-2020-03-09001-1-025251423           False
# 9  2016  sjmm_suf-2-02-2016-03-01299-0-000002017            True
#
#                                               reason  \
# 0  Mentions artificial intelligence as a disrupti...
# 1        No AI-related skills or concepts mentioned.
# 2  Mentions AI in the context of digital innovation.
# 3        No AI-related skills or concepts mentioned.
# 4        No AI-related skills or concepts mentioned.
# 5        No AI-related skills or concepts mentioned.
# 6  Mentions Machine Learning and Recommender Syst...
# 7  Job mentions BIM and IT-connected devices, ind...
# 8        No AI-related skills or concepts mentioned.
# 9  Mentions AI supply plans and AI Supply Chain P...
#
#                                   keywords
# 0                [artificial intelligence]
# 1                                     [ai]
# 2                [artificial intelligence]
# 3                            [data mining]
# 4                                     [ai]
# 5                                     [ai]
# 6  [machine-learning, recommender systems]
# 7                                [robotik]
# 8                       [autonomes fahren]
# 9                                     [ai]

# %%
# Display full text previews for the sampled ads
for i, row in sample.iterrows():
    ad_id = row['ad_id']; year = int(row['year'])
    print(f"[{i+1}] Year={year}  AI_Req={row['ai_requirement']}  Keywords={row['keywords']} Reason: {row['reason']}")
    txt = load_ad_text(ad_id, year)
    if not txt:
        print('  (no text found)')
    else:
        print(highlight(txt, row['keywords']))
    print('-'*80)
# Out:
# [1] Year=2023  AI_Req=True  Keywords=['artificial intelligence'] Reason: Mentions artificial intelligence as a disruptive technology.
# Are you deeply passionate about business strategy and customer-centric innovation with application to the financial services industry?
# Are you ready to build new ventures?
# Are you interested in deriving business value from latest technologies (web 3.0, DeFi, big data and <<artificial intelligence>>) disrupting the financial services industry?
#
# Then join our Strategy Financial Services team and be part of the future of finance!
#
# Our practice is Accenture Strategy Financial Services Switzerland and we shape the C-level agenda of leading financial service companies and fast-growing FinTechs.
# Operating from our global wealth management center of excellence in Zurich, we combine in-depth banking expertise with strategic excellence to solve our clients’ most pressing challenges.
#
# What awaits you
#
# Develop next generation banking business models that leverage blockchain technologies, DeFi, tokenization and digital assets
#
# Create digital product strategies that excite users and unlock new revenue streams
#
# M&A, venture building and fit-for-future restructuring to support the growth of our clients
#
# Develop intelligent operating models that allow companies to scale and adapt to constant market change
#
# Infuse creative thinking, thought leadership and agile mindsets to transform the Client culture
#
# Develop in-depth expertise in financial services industry and disseminate our point of view through publications and conferences
#
# Grow with the team and take end-to-end responsibility for global strategic projects
#
# Collaborate with experts ranging from research, technology, to user experience design to bring the best solutions to clients
# --------------------------------------------------------------------------------
# [2] Year=2023  AI_Req=False  Keywords=['ai'] Reason: No AI-related skills or concepts mentioned.
# Gestionn<<ai>>re programmation - 100%
#
# Gestionn<<ai>>re programmation - 100%
#
# Hôpitaux Universit<<ai>>res de Genève
#
# Genf
#
# bewerten
# Bewertung abgegeben
#
# 22.02.2023
#
# 	100%
#
# 	Festanstellung
#
# Online bewerben
#
# Avec plus de 12'000 collaborateurs et collaboratrices représentant 160 métiers, les Hôpitaux Universit<<ai>>res de Genève sont un établissement de référence au niveau national et international. Pour en savoir plus sur notre institution, prenez quelques minutes pour découvrir les moments forts et chiffres clefs de l’année 2021en cliquant
#
# 	ici
#
# 	.
#
# Le
#
# 	Département de la femme, de l'enfant et de l'adolescent
#
# 	a pour mission d’offrir des soins de qualité et adaptés aux besoins des femmes à chaque étape de leur vie et aux problèmes de santé auxquels sont confrontés les nouveau-nés, les enfants et les adolescentes et adolescents de leur n<<ai>>ssance jusqu'à l'âge de 16 ans. Il œuvre au développement des prestations de pointe et des pôles de compétence de spécialités.
#
# Au sein de notre service administratif, nous souh<<ai>>tons offrir à la patientèle, au public <<ai>>nsi qu'au personnel un service courtois, empathique et compétent, tant au téléphone qu'aux différents postes d'accueil.
#
# Gestionn<<ai>>re programmation - 100%
#
# Avec plus de 12'000 collaborateurs et collaboratrices représentant 160 métiers, les Hôpitaux Universit<<ai>>res de Genève sont un établissement de référence au niveau national et international. Pour en savoir plus sur notre institution, prenez quelques minutes pour découvrir les moments forts et chiffres clefs de l’année 2021en cliquant
#
# 	ici
#
# 	.
#
# Le
#
# 	Département de la femme, de l'enfant et de l'adolescent
#
# 	a pour mission d’offrir des soins de qualité et adaptés aux besoins des femmes à chaque étape de leur vie et aux problèmes de santé auxquels sont confrontés les nouveau-nés, les enfants et les adolescentes et adolescents de leur n<<ai>>ssance jusqu'à l'âge de 16 ans. Il œuvre au développement des prestations de pointe et des pôles de compétence de spécialités.
#
# Au sein de notre service administratif, nous souh<<ai>>tons offrir à la patientèle, au public <<ai>>nsi qu'au personnel un service courtois, empathique et compétent, tant au téléphone qu'aux différents postes d'accueil.
#
# Le secteur accueil, prise de rendez-vous et centrale téléphonique duDépartement de la femme, de l'enfant et de l'adolescent (DFEA) està la recherche d'un ou une collaboratrice pour compléter son équipe.
#
# Vous trav<<ai>>llez sur ces trois pôles,qui se trouvent dansles bâtiments de la pédiatrie et de la maternité et offrezun service adapté, courtois, empathique et compétent.
#
# Dans le cadre de votre fonction, vous accueillez etorientez les différentes personnes se présentant à l'accueil du prénatal et contribuez à la surveillance et à la sécurité des patients et patientes.
#
# Vous assurez la prise de rendez-vous de cet accueil, les téléphones, le tr<<ai>>tement des boîtes m<<ai>>ls liées à ces rendez-vous, <<ai>>nsi que de toutes les demandes de l’équipe médicale de ce service.
#
# Qualifications
# Vous êtes titul<<ai>>re d'un certificat fédéral de capacité d'employé ou employée de commerce ou d'un titre jugé équivalent avec auminimum de 3 ans d'expériencedans un service d'accueil.
#
# Vous avez une parf<<ai>>te maîtrisede lalanguefranç<<ai>>se orale et écrite (capacité rédactionnelle),possédez de bonnes conn<<ai>>ssances de l'angl<<ai>>s etmaîtrisez les logiciels usuels (Word, Excel, Outlook).
#
# La conn<<ai>>ssancedesoutils institutionnels (DPI, DPA), du système social suisse (LAMAL, <<AI>>, etc.)et de plusieurs langues (espagnol, etc.) sont des atouts considérables.
#
# Vous êtes à l'<<ai>>sedans les contacts, avez une bonne gestion du stress etêtes autonome tout en collaborant harmonieusement avec une grande équipe multidisciplin<<ai>>re.
#
# Informations supplément<<ai>>res
#
# Entrée en fonction : 1er m<<ai>> 2023
#
# Nombre de poste : 1
#
# Taux d’activité : 100%
#
# Classe de fonction : 10
#
# Contrat : CDD de 12mois
#
# Dél<<ai>> de candidature : 24.02.2023
#
# Demande de renseignement : Mme Pascale Théodet, cheffe de secteur,
#
# 	Écrire un em<<ai>>l
#
# Pour demander et consulter le cahier des charges, veuillez contacter Mme Cristina Garcia, adjointe RRH,
#
# 	Écrire un em<<ai>>l
#
# 	.
#
# Votre dossier de candidature doit comporter une lettre démontrant votre motivation, votre curriculum vitae, les copies des diplômes et attestations requis pour le poste et les 2 derniers certificats de trav<<ai>>l.
#
# Cette annonce s'adresse indistinctement aux femmes et aux hommes.
#
# Souh<<ai>>tant s’engager dans la lutte contre le chômage, les HUG encouragent les candidatures qui proviennent de l’Office cantonal de l’emploi.
#
# Adresse
#
# Rue Gabrielle-Perret-Gentil 4 1205 Genève
#
# Über die Firma
#
# Hôpitaux Universit<<ai>>res de Genève
#
# 5,0
#
# 	(2 Bewertungen)
#
# Firmenprofil mit Bewertungen und allen offenen Stellen
#
# Bei neuen Stellen benachrichtigt werden
# --------------------------------------------------------------------------------
# [3] Year=2021  AI_Req=True  Keywords=['artificial intelligence'] Reason: Mentions AI in the context of digital innovation.
# Business Development & Lead Digital Lab 60 - 100%
#
# Business Development & Lead Digital Lab 60 - 100%
#
# Switzerland Innovation Park Central
#
# —
# Rotkreuz
#
# 23.02.
#
# Fach ver ant wortung
#
# 60 – 100%
#
# E-Mail
#
# Facebook
#
# Twitter
#
# WhatsApp
#
# Link kopieren
#
# Bewerben
#
# Der Park Central hat sich als Teil des Netzwerks Switzerland Innovation der Open Innovation Philosophie verschrieben. Innerhalb des Themas "Building Excellence" arbeiten Wirtschaft, Wissenschaft und die öffentliche Hand gemeinsam an konkreten Fragestellungen und profitieren von interdisziplinären Kompetenzen. Für Unternehmen, Hochschulen, Institutionen, Start-Ups und Studierende ist der Park auf dem Campus Suurstoffi in Rotkreuz ein attraktiver Ort, um gemeinsam Innovationsprojekte voranzutreiben. Co-Working Spaces, Workshopräume und individuelle Zonen laden ein, innovativ zu sein. Wir sind überzeugt, dass durch gemeinsames Innovieren bessere Lösungen schneller entstehen. Entsprechend pflegen wir eine ganzheitliche Sichtweise. Durch die Kombination verschiedener Labs decken wir ökologisch, technologisch, wirtschaftlich und sozial relevante Aspekte ab und beschleunigen methodisch die Aktivitäten im Innovationsprozess.
#
# Business Development & Lead Digital Lab 60 - 100%
#
# Als dynamische und wachsende Organisation sind wir auf der Suche nach einer Person, die unser kleines, flexibles Team optimal ergänzt. In der Rolle
#
# Business Development & Lead Digital Lab
#
# kümmerst du dich in erster Linie um die Erweiterung unseres Ecosystems durch Mitglieder- und Partnerakquisition, die Konzeption und inhaltliche Weiterentwicklung des Digital Labs und die Erweiterung der Innovationsfähigkeit unserer Mitglieder. Dadurch gestaltest du den Park aktiv mit und hast die Möglichkeit, direkt Einfluss auf die Innovationsaktivitäten der Zentralschweiz und des Grossraums Zürich zu nehmen. Du arbeitest in einem hochmotivierten Umfeld an einem attraktiven, modernen Arbeitsort in Rotkreuz (15 Minuten nach Luzern, 35 Minuten nach Zürich HB). Wir freuen uns auf dich!
#
# Dein Job auf einen Blick ...
#
# Erweiterung unseres Ecosystems durch Mitglieder- und Partnerakquisition und Beziehungspflege
#
# Entwicklung und Etablierung einer Open Innovation Guideline und Unterstützung der Mitglieder beim Aufbau ihrer Innovationsfähigkeit
#
# Konzeption und inhaltliche Weiterentwicklung des Digital Labs mit Fokus auf digitales Planen und Bauen, Internet of Things und <<Artificial Intelligence>> im Kontext der gebauten Umwelt
#
# Initiierung und methodische Begleitung von Mitgliederprojekten im Rahmen des Digital Labs
#
# Mitarbeit in Parkprojekten
#
# aktives Mitdenken und permanentes Einbringen in die Ausrichtung des Parks
#
# Mitwirken im täglichen Parkbetrieb (Hosting, Raummanagement, Führungen, etc.)
#
# Du bringst mit ...
#
# Begeisterung und Interesse für Innovation, Business Development und digitale Themen
#
# Masterabschluss in Engineering, Informatik oder BWL mit Fokus Innovations- und Technologiemanagement
#
# 2-3 Jahre Berufserfahrung in einem ähnlichen Bereich respektive mit Industriehintergrund
#
# eine gewinnende Persönlichkeit mit guten Präsentationsskills
#
# eine rasche Auffassungsgabe und schnelle Reaktionsfähigkeit mit hohem Qualitätsanspruch
#
# Sprachen: Deutsch und Englisch (schriftlich, stilsicher)
#
# Willst du die Zukunft mitgestalten?
#
# Dann sende deine Bewerbung als PDF an
#
# Klicken und E-mail senden
#
# Switzerland Innovation Park Central
#
# Mr Sem  Mattli
#
# Geschäftsführer
#
# Suurstoffi 18b
#
# 6343 Rotkreuz
#
# 041 531 13 21
#
# Klicken und E-mail senden
#
# [wwwadr]
# --------------------------------------------------------------------------------
# [4] Year=2013  AI_Req=False  Keywords=['data mining'] Reason: No AI-related skills or concepts mentioned.
# Market Analyst, Travel & Aviation
#
# Réf. jobup : 836048 | Date: 1 Mars 2013
# Market Analyst, Travel & Aviation
# 1196 Gland
# Offre d'emploi de DKMA S.A.
# Market Analyst, Travel & Aviation
# Company
# DKMA is the world's leading provider of passenger focused research & advisory services. Our services help over 240 airports in 70 countries improve their passenger experience, providing better services, smoother operations and a more passenger friendly environment. Due to rapid growth we are looking for outstanding candidates for the position of Market Analyst available from May 2013.
# Job Description
# Airport Service Quality is a global benchmark of passenger services which is used by airports around the world to measure, monitor and improve the quality of services provided to passengers. As Market Analyst for the global ASQ initiative, you are responsible for day to day running of one of DKMA's key research projects, ASQ Performance.
# We are looking for someone with drive and motivation who will enjoy the challenge of managing and developing a global research project. The Market Analyst will be an enthusiastic, well organised person with a strong attention to detail and a willingness to learn continually. You will also be required to have excellent communication skills and to feel comfortable liaising with clients from all over the world. Occasional travel is also required.
# As a dynamic company we offer a work environment that will suit individuals looking for a challenging role with a wide variety of tasks, early responsibility and the opportunity to work in all aspects of an international business. This role will suit a recent university graduate.
# Your responsibilities:
# 	Liaise with and assist clients from a wide range of cultures
# 	Analyse data and ensure performance reports are delivered on time
# 	Develop new analysis and interpretation of results
# 	Present results to clients
# 	ASQ Survey Key Account responsibility for airports in the Middle East & Africa
# 	Assist DKMA directors in developing and growing the programme
# 	Essential skills:
# 	Excellent written and spoken English is mandatory for this position
# 	Outstanding organisational and people skills
# 	Excellent analytical capabilities
# 	Excellent MS office skills. SPSS / Visual Basic knowledge an advantage
# 	University Degree or equivalent
# 	Swiss / EU nationality or valid work permit for Switzerland
# If you are interested in joining a young, dynamic team and feel you fit this profile then apply now.
#
# Profil minimum requis :
# 	Swiss or C / B / G Permit or European EC citizen
# 	Education level: Bachelor (University, HES)
# Postulez maintenant !
# Agences de placement s'abstenir s.v.p.
# Emploi souhaité
# Profession
# Autres métiers
# Autres métiers
# Marketing / Médias / RP
# CRM / <<Data Mining>> / Etude de marché
# Management marque / produit
# Marketing
# Lieu: 1196 Gland
# Type de contrat : Permanent 100 %
# Informations sur le recruteur
# DKMA S.A.
# Ch du Riant-Coteau, 9
# 1196 Gland
# [wwwadr]
# Autres offres de DKMA S.A.
# --------------------------------------------------------------------------------
# [5] Year=2021  AI_Req=False  Keywords=['ai'] Reason: No AI-related skills or concepts mentioned.
# Gestionn<<ai>>re rentes (H/F) à 80% - 100%
#
# Gestionn<<ai>>re rentes (H/F) à 80% - 100%
#
# Office de l'assurance-invalidité pour le canton de Vaud
#
# Vevey
#
# bewerten
#
# Bewertung abgegeben
#
# Beworben
#
# Online bewerben
#
# L’Office de l’assurance-invalidité pour le canton de Vaud cherche à engager pour son département Prestations un :
#
# Gestionn<<ai>>re rentes (H/F) à 80% - 100%
#
# L’Office de l’assurance-invalidité pour le canton de Vaud cherche à engager pour son département Prestations un :
#
# Date d'entrée
#
# : 1er septembre 2021 ou date à convenir
#
# Classe salariale
#
# : 6 (
#
# Echelle salariale
#
# )
#
# Vos missions
#
# Votre rôle consiste à instruire les demandes de rentes de nos bénéfici<<ai>>res, en assurant le suivi et le tr<<ai>>tement d’un dossier, de sa réception à l’envoi de la décision.
#
# Dans ce but, vous récoltez les informations auprès des bénéfici<<ai>>res et des parten<<ai>>res, vous analysez les documents et vérifiez les conditions d’assurance. Vous vous tenez à disposition du bénéfici<<ai>>re pour le renseigner sur l’avancement de son dossier. Vous décidez ensuite du droit aux prestations <<AI>> et communiquez cette décision au bénéfici<<ai>>re.
#
# Cette mission s’effectue dans un environnement interdisciplin<<ai>>re et permet d’interagir avec des parten<<ai>>res d’horizons professionnels différents.
#
# Votre profil
#
# 	•  CFC d’employé-e de commerce
#
# 	•  expérience professionnelle de plusieurs années dans l’instruction de dossiers complexes au sein d’une assurance (impératif)
#
# 	•  le brevet fédéral en assurances sociales ser<<ai>>t un atout
#
# 	•  excellente capacité rédactionnelle et décisionnelle
#
# 	•  esprit d’analyse et de synthèse
#
# 	•  sens marqué de l’organisation
#
# 	•  bonnes compétences relationnelles
#
# 	•  intérêt pour le dom<<ai>>ne juridique et administratif
#
# Conn<<ai>>ssance de l’allemand : un plus
#
# Les offres de service comprendront tous les documents usuels (lettre de motivation, CV, copies des certificats de trav<<ai>>l et des diplômes) et seront adressées
#
# uniquement via Jobup.ch
#
# .
#
# Dél<<ai>> de postulation : 7 mars 2021
#
# Site Internet :
#
# [wwwadr]
#
# Adresse
#
# Service des Relations Hum<<ai>>nes 1800 Vevey
#
# Website
#
# [wwwadr]
#
# Office de l'assurance-invalidité pour le canton de Vaud
#
# 1800 Vevey / Vevey / evey
#
# Bewertung hinzufügen
#
# Geben Sie hier Ihre Bewertung für die Firma Office de l'assurance-invalidité pour le canton de Vaud ab!
#
# Bewertung abgegeben
# --------------------------------------------------------------------------------
# [6] Year=2011  AI_Req=False  Keywords=['ai'] Reason: No AI-related skills or concepts mentioned.
# Financial Controller <<AI>>
#
# About Syngenta:  Syngenta ist ein weltweit führendes Unternehmen mit mehr als 26 000 Mitarbeitenden in über 90 Ländern mit einem gemeinsamen Ziel: Bringing plant potential to life. Durch erstklassige Forschung, unsere globale Präsenz und die enge Zusammenarbeit mit unseren Kunden helfen wir, die Ernteerträge und die landwirtschaftliche Produktivität zu steigern, und tragen dazu bei, die Umwelt zu schützen sowie die Gesundheit und Lebensqualität zu verbessern. Weitere Informationen finden Sie unter: [wwwadr]
# .
#
# Vacancy:	Financial Controller <<AI>>
#
# Vacancy Type:  Permanent
# Business Unit:  Crop Protection
# Functional area:  Finance / Audit
# Location:	CH - Monthey
# Responsibilities:
# In this role you will:
#
# 	•  Provide to the operational organization of Active Ingredient (<<AI>>) production value adding and forward looking financial analysis to assist the decision making process on the site
#
# 	•  Promote financial discipline within the business and identify improvements focusing on cost development
#
# 	•  Proactively control and challenge the cash fixed costs for the <<AI>> production
#
# 	•  Collect comments for the key drivers of the variances versus Budget
#
# 	•  G<<ai>>n an understanding of <<AI>> production challenges through regular dialogue with business partners
#
# 	•  Provide accurate & complete management reports/presentations to Site Management Group (MSLT)
#
# 	•  Monitor and analyze the capitalized fixed production costs for the Monthey <<AI>> production
#
# 	•  Provide det<<ai>>led forecasts and full year estimates
#
# 	•  Coordinate and communicate proactively the planning processes for LE’s and Budgets for the whole site
#
# 	•  Provide value adding financial support to the Rep<<ai>>r & M<<ai>>ntenance department of the site
#
# 	•  Coach Engineers in financial matters and provide support for capital proposals for the area of Rep<<ai>>r & M<<ai>>ntenance and <<AI>> production
#
# 	•  Create reports for tracking and controlling FTE numbers in the different departments of the site
#
# 	•  Provide financial support to the K<<ai>>sten production site for the month end, planning and budgeting process
#
# 	•  Deputize Head of Finance – Swiss Manufacturing during his absences
#
# Requirements:	You have a Bachelor degree in Finance, accounting or in a related field and a minimum of 3 years controlling experience in the manufacturing industry. A previous exposure to manufacturing and Supply Ch<<ai>>n Finance on local and HQ levels and thorough production-accounting knowledge are desired. Moreover, you understand multi-site, complex logistic- and manufacturing environments. You are able to learn quickly and apply new knowledge, to work to tight deadlines without making compromises on accuracy or completeness. In addition, you are capable to built up strong networks to coordinate difficult issues in the finance space. You can speak French as well as English fluently, use effectively Microsoft office tools and are able to leverage knowledge of SAP/EDWH and production control systems into meaningful management information.
# --------------------------------------------------------------------------------
# [7] Year=2017  AI_Req=True  Keywords=['machine-learning', 'recommender systems'] Reason: Mentions Machine Learning and Recommender Systems.
# Wissenschaftliche/r Mitarbeiter/in
#
# Die Fernfachhochschule Schweiz (FFHS) bietet berufsbegleitende Bachelor-, Master- und
# Weiterbildungsstudiengange nach der «Blended Leaming»- Methode an. Ob in Lehre, Forschung oder
# Verwaltung - als verantwortungsvolle Arbeitgeberin zählen wir auf engagierte Mitarbeitende,die bereit sind, unsere Vision des zeit- und
# ortsunabhängigen Studierens mitzutragen. Das Laboratory für Web Science (LWS) betreibt angewandte Forschung auf den Gebieten
# «Data Science» und «Leaming Analytics» und bringt das erworbene Know-how mittels Forschungs- und Dienstleistungsprojekten in
# die Anwenderpraxis ein. Als Verstärkung unseres Teams suchen wir im «FFHS-Regionalzentrum Zürich/Regensdorf»
# (unmittelbar beim Bahnhof ) per sofort oder nach Vereinbarung zwei neue Mitarbeitende (zu je 80-100%).
#
# Wissenschaftliche/r Mitarbeiter/in
#
# 	•  Konzeption, Entwicklung und Implementierung von
# Big-Data-Architekturen
#
# 	•  Aufbereitung und Analyse grosser strukturierte sowie
# unstrukturierter Datenbestände
#
# 	•  Big-Data-Analysen in den Bereichen <<Machine-Learning>>
# sowie <<Recommender Systems>>
#
# 	•  Betreuung und Wartung eines Computer Clusters
#
# Wenn Sie sich angesprochen fühlen, finden Sie weitere
# Webseite: [wwwadr]
# Informationen sowie das Anforderungsprofil auf unserer
# Für inhaltliche Auskünfte steht Ihnen Dr. Beatrice Paoli, Leiterin, zur Verfügung. Wir freuen uns auf Ihre Bewerbung bis
# zum 31. März 2017 an: [email].
# --------------------------------------------------------------------------------
# [8] Year=2024  AI_Req=True  Keywords=['robotik'] Reason: Job mentions BIM and IT-connected devices, indicating AI relevance.
# Polier / Polierin Hochbau & Gewerbebau 100%
#
# Polier / Polierin Hochbau & Gewerbebau 100%
#
# METHABAU Gruppe
#
# Präsenz / Mobil
#
# Berufserfahrung
#
# Die METHABAU Gruppe ist die führende Anbieterin mehrgeschossiger Gewerbe- und Industriebauten mit hohem Vorfabrikationsgrad. Zudem bieten wir innovative Lösungen im Wohnungsbau. Ob Neubau, Umbau, Renovation oder Sanierung – wir übernehmen die gesamte Entwick lung, Planung und Realisierung. Im Bereich BIM-Planung (Building Information Modeling) zählen wir mit über 15 Jahren Erfahrung zu den Pionieren im digitalen Bauen.
# Wir bewirtschaften ein Immobilien-Portfolio von über 60 Rendite-Objekten im Wohn-, Büro-, Gewerbe- und Industriebau. An unseren drei Standorten mit rund 200 Mitarbeitenden und einer sechsköpfigen Gruppenleitung vereint die METHABAU Gruppe alle Fachkompetenzen und Stärken.
# Wir bauen gesamtheitlich. Mit Leidenschaft.
# WAS DICH BEWEGT / WAS DU MACHEN WIRST
#
# Du betreust und überwachst selbständig die Baustellen
#
# Du bist zuständig für eine effiziente, termin- und fachgerechte Führung / Organisation der Baustelle (Arbeiten ab BIM-Modell und mit <<Robotik>> Totalstation)
#
# Zudem priorisierst du die anstehenden Arbeiten und koordinierst das Material und Maschinen
#
# Du übernimmst die projektbezogene Führung der internen und externen Mitarbeitenden und erstellst Baustellenrapporte
#
# Ausserdem führst du Aufgaben in den Bereichen der Arbeitsvorbereitung, Bauplatzorganisation und Administration durch
#
# WER DU BIST / DEINE FÄHIGKEITEN & TALENTE
#
# Du verfügst über eine abgeschlossene Lehre als Maurer, vorzugsweise mit schulischer Weiterbildung
#
# Du hast mehrjährige Berufserfahrung als Polier
#
# Du trägst aktiv zur Motivation und Entwicklung eines Teams bei und erzielst gemeinsam mit deinen Mitarbeitenden hervorragende Ergebnisse indem du jeden Tag als Vorbild voran gehst
#
# Du bist ein proaktiver Entscheidungsträger/in mit ausgeprägten vernetztem Denken und weisst Prioritäten zu setzen
#
# Du verfügst über gute EDV-Anwenderkenntnisse und hast Interesse an Geräten mit IT- Anbindung
#
# Du fühlst dich in einem hochdynamischen und anregenden Umfeld wohl
#
# WARUM SOLLTEST DU DICH BEWERBEN
#
# Du findest bei uns eine zukunftsorientierte und anspruchsvolle Aufgabe, bei der du spannende Bauprojekte mitprägen kannst
#
# Wir bieten Entwicklungsmöglichkeiten und Eigenverantwortung in der Wahrnehmung deiner Funktion
#
# Es erwartet dich ein kollegiales Arbeitsumfeld und ein eingespieltes Team
#
# Wir unterstützen dich in deiner weiteren Karriereplanung
#
# Moderne Betriebsinfrastruktur
#
# Wir bieten dir ein gratis Clever fit-Abo
#
# Kostenloser Parkplatz
#
# Willst du ein Mitglied der METHABAU Gruppe werden?
# Dann freuen wir uns auf deine elektronische Bewerbung.
# Bei Rückfragen zum Bewerbungsprozess ist das HR Recruitingcenter gerne für dich da.
# Tel.: +41 71 521 12 58.
#
# Jessica Hornauer
#
# Senior Talent Manager
#
# Jürg Wagner
#
# Gruppenleitung
# --------------------------------------------------------------------------------
# [9] Year=2020  AI_Req=False  Keywords=['autonomes fahren'] Reason: No AI-related skills or concepts mentioned.
# Lieferantenauditor/Auditor CQI (m/w)
#
# thyssenkrupp, das sind mehr als 161.000 Mitarbeiter in 79 Ländern und knapp €43 Mrd. Umsatz im Jahr. Das ist Automotive, Logistik, Anlagenbau, Stahlproduktion, Aufzugsbau und noch mehr. Auf der ganzen Welt, in grossen und in kleinen Unternehmen, aber immer gemeinsam. Das sind über 200 Jahre Industriegeschichte und modernste Technologie. Wir haben eine Aufgabe, die zu Ihnen passt, die Ihre Neugier weckt und Sie herausfordert.
#
# Lieferantenauditor/Auditor CQI (m/w)
# thyssenkrupp Presta AG, Eschen
#
# Die thyssenkrupp Presta AG gehört zu den weltweit erfolgreichsten Herstellern von Lenksystemen und ist Technologieführer im Bereich der Massivumformung. Damit schaffen wir die technologischen Voraussetzungen für Steer-by-Wire, Elektromobilität oder <<autonomes Fahren>>. Gemeinsam mit unseren mehr als 8.500 Mitarbeitern an 17 Standorten sowie den weltweit bekanntesten Automobilherstellern, bringen wir die Zukunft auf die Strasse. Leidenschaft für das Automobil, Dynamik, Innovationsfreude und Do-It-Mentalität - das zeichnet uns in unserer Arbeit genauso aus, wie das Streben nach höchster Sicherheit und Qualität. Sie wollen mit uns auf die Überholspur? Dann steigen Sie jetzt ein bei der thyssenkrupp Presta AG und werden Sie ein Teil von uns!
#
# Das können Sie bei uns bewegen:
#
# 	Sie sind verantwortlich für die selbständige Planung und Durchführung von Prozess- und Wärmebehandlungsaudits bei Lieferanten innerhalb der thyssenkrupp Presta Steering, inkl. Berichterstattung
# 	Die Überwachung von Korrekturmassnahmen und ggf. Nachauditierung bei Abweichungen liegt ebenfalls in Ihrem Aufgabengebiet
#
# Damit überzeugen Sie uns:
#
# 	Sie verfügen über ein abgeschlossenes Studium im Bereich Ingenieurwissenschaften mit Fachrichtung Maschinenbau oder eine gleichwertige Ausbildung
# 	Eine mehrjährige praktische Berufserfahrung im Qualitätsmanagement, speziell im Bereich Automotive können Sie vorweisen
# 	Wünschenswert wären eine mehrjährige Erfahrung im Bereich Wärmebehandlung; AIAG CQI 9 Assessments und weitere CQI Assessments
# 	Eine Ausbildung zum Auditor, sowie vertiefte Kenntnisse über ISO 9001ff, IATF 16949 runden Ihr Profil ab (Idealerweise zertifizierte VDA 6.3 Auditor Ausbildung)
# 	Neben Deutsch können Sie sehr gut in der englischen Sprache (Wort und Schrift) kommunizieren
# 	Ihre Bereitschaft zu Reisen liegt bei >60%
#
# Das können Sie von uns erwarten:
#
# Für uns ist es selbstverständlich Ihnen neben attraktiven Anstellungsbedingungen und Sozialleistungen optimale Rahmenbedingungen zu bieten. Dazu gehören unter anderem:
#
# 	Von Kopf bis Fuss: Bei uns finden Sie höchste Standards für Arbeitssicherheit und Gesundheit. Ergonomische Arbeitsplätze, Obsttage, WEFit – unser firmeneigenes Fitnesscenter und weitere flexible Angebote rund um die Gesundheitsförderung und -vorsorge steigern Ihr Wohlbefinden
# 	Eine steile Lernkurve durch abwechslungsreiche Aufgaben und Projekte mit hoher Eigenverantwortung
# 	Die Einbindung in ein dynamisches Team und eine Du-Kultur, die von Offenheit, aktiver Mitgestaltung und Teamarbeit geprägt ist. Regelmässige Team- und Firmenevents schweissen zusammen und verbinden uns
# 	Laufende Einarbeitungs- und Weiterbildungsprogramme, bei denen Sie Ihr Potenzial entfalten können
#
# Wir wertschätzen Vielfalt und begrüssen daher alle Bewerbungen - unabhängig von Geschlecht, sozialer Herkunft, Religion/Weltanschauung, Alter und Identität. Tanja Meier freut sich über Ihre aussagekräftige und vollständige Onlinebewerbung.
#
# Tanja Meier
# HR Spezialistin Recruiting
# Sourcing & Recruiting
# Human Resources
#
# thyssenkrupp Presta AG
# Human Resources
# Essanestrasse 10
# 9492 Eschen
# Fürstentum Liechtenstein
#
# Telefon: +423 / 377 67 70
# --------------------------------------------------------------------------------
# [10] Year=2016  AI_Req=True  Keywords=['ai'] Reason: Mentions AI supply plans and AI Supply Chain Planner.
# Internship in Toll Manufacturing (12 months)
#
# About Syngenta:
#
# Syngenta is one of the world's leading companies with more than 28,000 employees in over 90 countries dedicated to our purpose: Bringing plant potential to life. Through world-class science, global reach and commitment to our customers we help to increase crop productivity, protect the environment and improve health and quality of life.  For more information about us please go to [wwwadr]
#
# Vacancy Reference ID: 	794153
#
# Vacancy:	Internship in Toll Manufacturing (12 months)
#
# Vacancy Type: 	Internship
# Business Unit: 	Crop Protection
# Functional area: 	Supply Ch<<ai>>n / Logistics
# Location:	CH - Basel
# Responsibilities:	Syngenta is looking for an Intern in Toll Manufacturing for a period of 12 months. In this role you will:
#
# 	•  m<<ai>>nt<<ai>>n the det<<ai>>led <<AI>> supply plans across one or more defined tollers and product portfolio, providing options to meet upsides and downsides. Work within a Tactical Supply Plan agreed with the <<AI>> SCP.
#
# 	•  supervise co-ordination along the supply ch<<ai>>n, especially with <<AI>> Supply Ch<<ai>>n Planner, Vendor Schedulers and Toller to manage the production plan and ex-works shipments over a zero to end current season horizon.
#
# 	•  contact with Order Management, <<AI>> SCPs, Purchasing/Technical support, Site Production teams, Tollers, Vendor Schedulers
# Requirements:
#
# 	•  Bachelor's degree in Supply Ch<<ai>>n
#
# 	•  Understanding of the agrochemical market.
#
# 	•  SAP knowledge.
#
# 	•  MRPII knowledge.
#
# 	•  Understanding & application of basic IT and ERP tools.
#
# 	•  Product Life cycle management.
#
# 	•  Manufacturing knowledge.
#
# 	•  Understanding planning parameters, (master) data management & data integrity.
#
# 	•  Advanced capacity planning skills, end to end process.
#
# 	•  Experience of the key interfaces within the supply ch<<ai>>n.
#
# 	•  Understanding Risk Management within the Supply Ch<<ai>>n.
#
# 	•  Good understanding of Health and Safety and current best practices.
#
# 	•  Effective stakeholder & expectation management.
#
# 	•  Good interpersonal communication, both written and verbal.
#
# 	•  Fluency in English required, ideally additional language like French or German
# --------------------------------------------------------------------------------
