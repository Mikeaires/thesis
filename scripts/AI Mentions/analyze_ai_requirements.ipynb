# %% [markdown]
# # AI Requirements Debug
# Inspect model outputs in ai_job_requirements_simple.json and the full job texts.

# %%
from pathlib import Path
import json, bz2, re
import pandas as pd
from collections import defaultdict

# Robust root resolution for notebooks
def find_root(start: Path) -> Path:
    for p in [start] + list(start.parents):
        if (p / 'Results Datasets').exists():
            return p
    return start

ROOT = find_root(Path.cwd())
REQ_PATH = ROOT / 'Results Datasets' / 'ai_mentions' / 'ai_job_requirements_simple.json'
MATCH_PATH = ROOT / 'Results Datasets' / 'ai_mentions' / 'ai_keyword_matches_fulltext.json'
TEXT_DIR = ROOT / 'Base Dataset' / 'Data' / '699_SJMM_Data_TextualData_v10.0' / 'sjmm_suf_ad_texts'
print('Reading:', REQ_PATH)
req_data = json.loads(REQ_PATH.read_text(encoding='utf-8')) if REQ_PATH.exists() else {}
match_data = json.loads(MATCH_PATH.read_text(encoding='utf-8')) if MATCH_PATH.exists() else {}
len(req_data), len(match_data)
# Out:
# Reading: /Users/miguel/Documents/Master Thesis/Thesis/Results Datasets/ai_mentions/ai_job_requirements_simple.json
# (15, 15)

# %%
# Flatten requirements to a DataFrame
rows = []
for year, ads in req_data.items():
    for ad_id, res in ads.items():
        rows.append({
            'year': int(year),
            'ad_id': ad_id,
            'ai_requirement': bool(res.get('ai_requirement', False)),
            'reason': res.get('reason', '')
        })
df = pd.DataFrame(rows)
df.sort_values(['year','ad_id'], inplace=True)
print('Rows:', len(df), '| True:', df['ai_requirement'].sum())
per_year = (df.groupby('year')['ai_requirement']
             .agg(['sum','count'])
             .rename(columns={'sum':'true','count':'total'}))
per_year['pct'] = (per_year['true'] / per_year['total'] * 100).round(2)
per_year.tail(10)
# Out:
# Rows: 614 | True: 312
#       true  total    pct
# year
# 2015     5     23  21.74
# 2016     7     23  30.43
# 2017    17     48  35.42
# 2018    21     48  43.75
# 2019    35     66  53.03
# 2020    29     53  54.72
# 2021    45     65  69.23
# 2022    47     61  77.05
# 2023    34     56  60.71
# 2024    52     75  69.33

# %%
# Build per-ad keyword list from matches
ad_keywords = defaultdict(set)
for year, ads in match_data.items():
    for ad_id, matches in ads.items():
        for m in matches:
            kw = (m.get('keyword') or '').strip()
            if kw:
                ad_keywords[ad_id].add(kw)
df['keywords'] = df['ad_id'].map(lambda x: sorted(ad_keywords.get(x, [])))
df.head(50)
# Out:
#     year                                    ad_id  ai_requirement  \
# 2   2010  sjmm_suf-1-01-2010-03-02111-0-000000003           False
# 4   2010  sjmm_suf-1-01-2010-03-03112-0-000000038           False
# 0   2010  sjmm_suf-1-01-2010-03-05108-0-000000001           False
# 3   2010  sjmm_suf-1-01-2010-03-06111-0-000000009           False
# 1   2010  sjmm_suf-1-01-2010-03-07107-0-000000001            True
# 13  2010  sjmm_suf-2-01-2010-03-00354-0-000001384           False
# 16  2010  sjmm_suf-2-01-2010-03-00680-0-000002102            True
# 10  2010  sjmm_suf-2-01-2010-03-00945-0-000000584           False
# 11  2010  sjmm_suf-2-01-2010-03-00945-0-000000593           False
# 12  2010  sjmm_suf-2-01-2010-03-00970-0-000001350           False
# 5   2010  sjmm_suf-2-01-2010-03-00986-0-000000153            True
# 6   2010  sjmm_suf-2-01-2010-03-00986-0-000000187           False
# 7   2010  sjmm_suf-2-01-2010-03-00986-0-000000198            True
# 17        No AI-related skills or concepts mentioned.
# 19       No mention of AI-related skills or concepts.
# 18        No AI-related skills or concepts mentioned.
# 36        No AI-related skills or concepts mentioned.
# 31        No AI-related skills or concepts mentioned.
# 37        No AI-related skills or concepts mentioned.
# 27        No AI-related skills or concepts mentioned.
# 28        No AI-related skills or concepts mentioned.
# 34        No AI-related skills or concepts mentioned.
# 20  Mentions AI Supply Chain Planners as key conta...
# 22        No AI-related skills or concepts mentioned.
# 35  Mentions Data Mining and Business Intelligence...
# 32  Mentions collaboration with IT Services AI-Bas...
# 25        No AI-related skills or concepts mentioned.
# 21       No mention of AI-related skills or concepts.
# 23        No AI-related skills or concepts mentioned.
# 26  Job mentions advanced analytics and predictive...
# 29        No AI-related skills or concepts mentioned.
# 30       No mention of AI-related skills or concepts.
# 24  Mentions development of algorithms for image a...
# 33  Knowledge of machine translation technologies ...
# 41        No AI-related skills or concepts mentioned.
# 38        No AI-related skills or concepts mentioned.
# 39        No AI-related skills or concepts mentioned.
# 40        No AI-related skills or concepts mentioned.
# 58        No AI-related skills or concepts mentioned.
# 59        No AI-related skills or concepts mentioned.
# 61  Job mentions data mining and statistical analy...
# 62  Job mentions predictive modelling, an AI-relat...
# 60  Job mentions using computer vision, an AI-rela...
# 57     Mentions use of speech recognition technology.
# 50        No AI-related skills or concepts mentioned.
# 49  No explicit mention of AI-related skills or co...
#
#                                              keywords
# 2                                           [robotik]
# 4                                           [robotik]
# 0                                           [robotik]
# 3                                                [ai]
# 1                                                [ai]
# 13                             [intelligente systeme]
# 16                                      [data mining]
# 10                                         [robotics]
# 11                                         [robotics]
# 12                          [vorausschauende wartung]
# 5                                                [ai]
# 6                                                [ai]
# 7                                                [ai]
# 14                                      [text mining]
# 15                          [algorithmus-entwicklung]
# 8                                                [ai]
# 9                                           [robotik]
# 17                                               [ai]
# 19                                              [llm]
# 18                                               [ai]
# 36                                  [online learning]
# 31                                               [ai]
# 37                                              [llm]
# 27                                         [robotics]
# 28                                         [robotics]
# 34                          [vorausschauende wartung]
# 20                                               [ai]
# 22                                               [ai]
# 35                                      [text mining]
# 32                                               [ai]
# 25                                      [data mining]
# 21                                               [ai]
# 23                                              [llm]
# 26  [anomaly detection, data mining, predictive mo...
# 29                                          [robotik]
# 30                                         [robotics]
# 24                                  [objekterkennung]
# 33                              [machine translation]
# 41                                               [ai]
# 38                                               [ai]
# 39                                               [ai]
# 40                                               [ai]
# 58                                         [robotics]
# 59                                         [robotics]
# 61                                      [data mining]
# 62                             [predictive modelling]
# 60                                  [computer vision]
# 57                                  [spracherkennung]
# 50                                      [fine-tuning]
# 49                                      [data mining]

# %%
df.group
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/b8/xcnlw57x6_3gqylzftwx02tr0000gn/T/ipykernel_21952/1380114043.py in ?()
# ----> 1 df.group
#
# /opt/anaconda3/envs/Parad/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'group'

# %%
# Utilities to load full text and highlight keywords
def extract_year_from_ad(ad_id: str):
    for part in ad_id.split('-'):
        if part.isdigit() and 1900 <= int(part) <= 2100:
            return int(part)
    return None

def load_ad_text(ad_id: str, year_hint: int | None = None):
    year = year_hint or extract_year_from_ad(ad_id)
    if year is None:
        return ''
    p = TEXT_DIR / f'ads_sjmm_{year}.jsonl.bz2'
    if not p.exists():
        return ''
    with bz2.open(p, 'rt', encoding='utf-8') as fh:
        for line in fh:
            try:
                obj = json.loads(line)
            except Exception:
                continue
            if obj.get('adve_iden_adve') == ad_id:
                txt = obj.get('adve_text_adve') or ''
                return txt if isinstance(txt, str) else ''
    return ''

def highlight(text: str, keywords: list[str]):
    out = text
    for kw in sorted(set(keywords), key=len, reverse=True):
        if not kw:
            continue
        try:
            pat = re.compile(re.escape(kw), re.IGNORECASE)
            out = pat.sub(lambda m: '<<' + m.group(0) + '>>', out)
        except Exception:
            pass
    return out

# %%
# Filters
FILTER_YEAR = None  # int or None
FILTER_REQUIREMENT = None  # True / False / None
FILTER_SUBSTR = ''  # substring in reason or keywords

q = df.copy()
if FILTER_YEAR is not None:
    q = q[q['year'] == int(FILTER_YEAR)]
if FILTER_REQUIREMENT is not None:
    q = q[q['ai_requirement'] == bool(FILTER_REQUIREMENT)]
if FILTER_SUBSTR:
    s = FILTER_SUBSTR.lower()
    q = q[q['reason'].str.lower().str.contains(s) | q['keywords'].apply(lambda ks: any(s in k.lower() for k in ks))]
q.head(20)
# Out:
#     year                                    ad_id  ai_requirement  \
# 2   2010  sjmm_suf-1-01-2010-03-02111-0-000000003           False
# 4   2010  sjmm_suf-1-01-2010-03-03112-0-000000038           False
# 0   2010  sjmm_suf-1-01-2010-03-05108-0-000000001           False
# 3   2010  sjmm_suf-1-01-2010-03-06111-0-000000009           False
# 1   2010  sjmm_suf-1-01-2010-03-07107-0-000000001            True
# 13  2010  sjmm_suf-2-01-2010-03-00354-0-000001384           False
# 16  2010  sjmm_suf-2-01-2010-03-00680-0-000002102            True
# 10  2010  sjmm_suf-2-01-2010-03-00945-0-000000584           False
# 11  2010  sjmm_suf-2-01-2010-03-00945-0-000000593           False
# 12  2010  sjmm_suf-2-01-2010-03-00970-0-000001350           False
# 5   2010  sjmm_suf-2-01-2010-03-00986-0-000000153            True
# 6   2010  sjmm_suf-2-01-2010-03-00986-0-000000187           False
# 7   2010  sjmm_suf-2-01-2010-03-00986-0-000000198            True
# 14  2010  sjmm_suf-2-01-2010-03-01270-0-000001774            True
# 15  2010  sjmm_suf-2-01-2010-03-01270-0-000001790           False
# 8   2010  sjmm_suf-3-01-2010-03-09001-0-000000221           False
# 9   2010  sjmm_suf-3-01-2010-03-09001-0-000000322           False
# 17  2011  sjmm_suf-1-01-2011-03-01214-0-000000004           False
# 19  2011  sjmm_suf-1-01-2011-03-03107-0-000000018           False
# 18  2011  sjmm_suf-1-01-2011-03-06109-0-000000006           False
#
#                                                reason  \
# 2         No AI-related skills or concepts mentioned.
# 4         No AI-related skills or concepts mentioned.
# 0         No AI-related skills or concepts mentioned.
# 3         No AI-related skills or concepts mentioned.
# 1         Mentions collaboration with AI consultants.
# 13        No AI-related skills or concepts mentioned.
# 16  Mentions statistical tools and data mining met...
# 10        No AI-related skills or concepts mentioned.
# 11        No AI-related skills or concepts mentioned.
# 12        No AI-related skills or concepts mentioned.
# 5   Mentions creation of high quality AI profile i...
# 6         No AI-related skills or concepts mentioned.
# 7   Job mentions maintaining a high quality AI pro...
# 14  Mentions data mining and business intelligence...
# 15  No explicit mention of AI-related skills or co...
# 8         No AI-related skills or concepts mentioned.
# 9         No AI-related skills or concepts mentioned.
# 17        No AI-related skills or concepts mentioned.
# 19       No mention of AI-related skills or concepts.
# 18        No AI-related skills or concepts mentioned.
#
#                      keywords
# 2                   [robotik]
# 4                   [robotik]
# 0                   [robotik]
# 3                        [ai]
# 1                        [ai]
# 13     [intelligente systeme]
# 16              [data mining]
# 10                 [robotics]
# 11                 [robotics]
# 12  [vorausschauende wartung]
# 5                        [ai]
# 6                        [ai]
# 7                        [ai]
# 14              [text mining]
# 15  [algorithmus-entwicklung]
# 8                        [ai]
# 9                   [robotik]
# 17                       [ai]
# 19                      [llm]
# 18                       [ai]

# %%
# Inspect a single ad
AD_ID = q['ad_id'].iloc[0] if len(q) else (df['ad_id'].iloc[0] if len(df) else '')
print('Ad ID:', AD_ID)
row = df[df['ad_id'] == AD_ID].iloc[0] if AD_ID else None
row
# Out:
# Ad ID: sjmm_suf-1-01-2010-03-02111-0-000000003
# year                                                     2010
# ad_id                 sjmm_suf-1-01-2010-03-02111-0-000000003
# ai_requirement                                          False
# reason            No AI-related skills or concepts mentioned.
# keywords                                            [robotik]
# Name: 2, dtype: object

# %%
# Show full text with highlighted keywords (first 2000 chars)
if AD_ID:
    txt = load_ad_text(AD_ID, int(row['year']))
    print('Text length:', len(txt))
    if txt:
        print(highlight(txt, row['keywords'])[:2000])
else:
    print('No AD_ID available')
# Out:
# Text length: 1981
# Dozent/in für Sensortechnik und Mechatronik
#
# [bild]
# Berner Fachhochschule
# Haut école spécialisée bernoise
# Technik und Informatik
# Technique et informatique
# Die Berner Fachhochschule BFH ist eine anwendungsorientierte Hochschule. 27 Bachelorstudiengänge und 19 Masterstudiengänge, fundierte Forschungsdienstleisungen und ein breites Weiterbildungsangebot geben ihr Profil. Praxisnah, interdisziplinär und in einem internationalen Kontext. Das Departement Technik und Informatik sucht für den Fachbereich Mikrotechnik und Medizintechnik eine/n
# Dozent/in für Sensortechnik und Mechatronik
# (100 Prozent)
# sowie eine/n
# Dozent/in für <<Robotik>>
# (80 bis 100 Prozent)
# Sensortechnik: Sie haben mehrjährige praktische Erfahrung im Bereich Sensortechnik und Mechatronik, sowie RFID im Umfeld der Mikrotechnik, <<Robotik>>technik oder Medizintechnik.
# <<Robotik>>: Für die Stelle als Dozent/in haben Sie fundierte Erfahrung im Bereich <<Robotik>>, sowie in Regelungstechnik und Informatik.
# Ihre Aufgaben:
# Unterricht im Bachelorstudiengang Mikrotechnik und Medizintechnik
# Betreuung von Studienarbeiten auf Stufe Bachelor und Master
# Akquirierung, Leitung und Durchführung von angewandten Forschungsprojekten
# Zusammenarbeit mit der Industrie
# Unterricht in Deutsch und Französisch
# Wir bieten:
# Eine höchst interessante Arbeitsstelle in einem anregenden Umfeld
# Gut eingerichtete Labore mit wissenschaftlichen Mitarbeitern
# Ein Dozentenkollegium, das sich auf eine Verstärkung in einem erfolgreichen Wachstumsgebiet sehr freut.
# Eine erfolgreiche Zusammenarbeit mit der Industrie
# Ein Arbeitsort in Biel
# Haben wir Ihr Interesse geweckt? Telefonische Auskunft erteilt Ihnen gerne Herr [kper], Leiter des Fachbereichs Mikrotechnik, Telefon [tel], mail:[email]
# Wir freuen uns auf Ihre schriftliche Bewerbung bis spätestens [dat] an:
# Berner Fachhochschule, Technik und Informatik, zu Handen von Frau [kper], Human Resources, [adr], 2501 Biel Bienne. Per Mail an: [email].
# Weitere Stellen unter [wwwadr] oder [wwwadr]
# [wwwadr]
