# %% [markdown]
# # Compare v7 vs v7 rerun
#
# Quick checks of label deltas between the original v7 run and the v7 rerun (2010–2024).

# %%
from pathlib import Path
import json
import pandas as pd

# Compute project root robustly for notebooks (no __file__)
def get_root() -> Path:
    p = Path.cwd()
    # Walk up until we find the marker folder
    for _ in range(5):
        if (p / "Results Datasets").exists():
            return p
        p = p.parent
    return Path.cwd()

ROOT = get_root()
RES_DIR = ROOT / "Results Datasets" / "ai_mentions" / "results" / "requirements"
V7_DIR = RES_DIR / "v7"
V7_RERUN = RES_DIR / "v7_rerun" / "ai_job_requirements_all_2010_2024_v7_rerun.json"

def load_results(path: Path) -> pd.DataFrame:
    data = json.loads(path.read_text(encoding="utf-8"))
    rows = []
    for y_str, ads in data.items():
        try:
            year = int(y_str)
        except Exception:
            continue
        for ad_id, payload in (ads or {}).items():
            rows.append(
                {
                    "year": year,
                    "ad_id": ad_id,
                    "ai_requirement": str(payload.get("ai_requirement", "False")).capitalize(),
                    "reason": payload.get("reason", ""),
                    "keywords": payload.get("keywords", []),
                }
            )
    return pd.DataFrame(rows)

def load_v7_all() -> pd.DataFrame:
    frames = []
    for p in sorted(V7_DIR.glob("ai_job_requirements_all_*_v7.json")):
        try:
            frames.append(load_results(p))
        except Exception:
            continue
    if not frames:
        return pd.DataFrame(columns=["year", "ad_id", "ai_requirement", "reason", "keywords"])
    df = pd.concat(frames, ignore_index=True)
    return df.drop_duplicates(subset=["year", "ad_id"], keep="last")

def load_v7_rerun() -> pd.DataFrame:
    if not V7_RERUN.exists():
        return pd.DataFrame(columns=["year", "ad_id", "ai_requirement", "reason", "keywords"])
    return load_results(V7_RERUN)

v7_df = load_v7_all()
v7r_df = load_v7_rerun()

v7_df = v7_df.rename(columns={
    "ai_requirement": "ai_requirement_v7",
    "reason": "reason_v7",
    "keywords": "keywords_v7",
})
v7r_df = v7r_df.rename(columns={
    "ai_requirement": "ai_requirement_v7_rerun",
    "reason": "reason_v7_rerun",
    "keywords": "keywords_v7_rerun",
})

df = v7_df.merge(v7r_df, on=["year", "ad_id"], how="outer")
df.head()

print(f"rows v7: {len(v7_df):,}")
print(f"rows v7 rerun: {len(v7r_df):,}")
print(f"merged rows: {len(df):,}")
# Out:
# rows v7: 2,546
# rows v7 rerun: 2,546
# merged rows: 2,546

# %%
# Overall contingency table
overall = df.pivot_table(
    index="ai_requirement_v7",
    columns="ai_requirement_v7_rerun",
    values="ad_id",
    aggfunc="count",
    fill_value=0,
)
overall
# Out:
# ai_requirement_v7_rerun  False  Maybe  True
# ai_requirement_v7
# Maybe                     1411    504   232
# True                        88    178   133

# %%
# Per-year label counts per version
per_year = (
    df.melt(id_vars=["year", "ad_id"], value_vars=["ai_requirement_v7", "ai_requirement_v7_rerun"], var_name="version", value_name="label")
    .pivot_table(index=["year", "version"], columns="label", values="ad_id", aggfunc="count", fill_value=0)
    .sort_index()
)
per_year
# Out:
# label                         False  Maybe  True
# year version
# 2014 ai_requirement_v7            0    134     7
#      ai_requirement_v7_rerun    103     31     7
# 2015 ai_requirement_v7            0    152    13
#      ai_requirement_v7_rerun    103     37    25
# 2016 ai_requirement_v7            0    176    12
#      ai_requirement_v7_rerun    119     38    31
# 2017 ai_requirement_v7            0    215    25
#      ai_requirement_v7_rerun    148     47    45
# 2018 ai_requirement_v7            0    213    32
#      ai_requirement_v7_rerun    138     71    36
# 2019 ai_requirement_v7            0    230    48
#      ai_requirement_v7_rerun    168     80    30
# 2020 ai_requirement_v7            0    217    39
#      ai_requirement_v7_rerun    149     71    36
# 2021 ai_requirement_v7            0    232    62
#      ai_requirement_v7_rerun    172     74    48
# 2022 ai_requirement_v7            0    233    60
#      ai_requirement_v7_rerun    170     84    39
# 2023 ai_requirement_v7            0    119    42
#      ai_requirement_v7_rerun     81     57    23
# 2024 ai_requirement_v7            0    226    59
#      ai_requirement_v7_rerun    148     92    45

# %%
# Flip summary and sample
flips = df[df["ai_requirement_v7"] != df["ai_requirement_v7_rerun"]].copy()
flip_counts = flips.groupby(["ai_requirement_v7", "ai_requirement_v7_rerun"]).size().reset_index(name="count")
flip_counts
# Out:
#   ai_requirement_v7 ai_requirement_v7_rerun  count
# 0             Maybe                   False   1411
# 1             Maybe                    True    232
# 2              True                   False     88
# 3              True                   Maybe    178

# %%
flips_sample = flips.head(50)[[
    "year", "ad_id", "ai_requirement_v7", "ai_requirement_v7_rerun", "reason_v7", "reason_v7_rerun", "keywords_v7", "keywords_v7_rerun"
]]
flips_sample
# Out:
#     year                                    ad_id ai_requirement_v7  \
# 0   2014  sjmm_suf-1-01-2014-03-01121-0-000000001             Maybe
# 1   2014  sjmm_suf-1-01-2014-03-02111-0-000000009             Maybe
# 2   2014  sjmm_suf-1-01-2014-03-02201-0-000000016             Maybe
# 4   2014  sjmm_suf-1-01-2014-03-03112-0-000000022             Maybe
# 5   2014  sjmm_suf-1-01-2014-03-03118-0-000000011             Maybe
# 6   2014  sjmm_suf-1-01-2014-03-03118-0-000000019             Maybe
# 7   2014  sjmm_suf-1-01-2014-03-03120-0-000000001             Maybe
# 8   2014  sjmm_suf-1-01-2014-03-04124-0-000000083             Maybe
# 11  2014  sjmm_suf-2-02-2014-03-00020-0-000001520             Maybe
# 12  2014  sjmm_suf-2-02-2014-03-00046-0-000002586             Maybe
# 13  2014  sjmm_suf-2-02-2014-03-00046-0-000002591             Maybe
# 14  2014  sjmm_suf-2-02-2014-03-00046-0-000002592             Maybe
# 15  2014  sjmm_suf-2-02-2014-03-00095-0-000002969             Maybe
# 16  2014  sjmm_suf-2-02-2014-03-00095-0-000002970              True
# 17  2014  sjmm_suf-2-02-2014-03-00122-0-000002639             Maybe
# 18  2014  sjmm_suf-2-02-2014-03-00137-0-000003493             Maybe
# 20  2014  sjmm_suf-2-02-2014-03-00173-0-000003269             Maybe
# 21  2014  sjmm_suf-2-02-2014-03-00189-0-000001054             Maybe
# 23  2014  sjmm_suf-2-02-2014-03-00467-0-000001888             Maybe
# 25  2014  sjmm_suf-2-02-2014-03-00477-0-000002827             Maybe
# 26  2014  sjmm_suf-2-02-2014-03-00491-0-000003616             Maybe
# 27  2014  sjmm_suf-2-02-2014-03-00497-0-000001159             Maybe
# 29  2014  sjmm_suf-2-02-2014-03-00501-0-000002768             Maybe
# 30  2014  sjmm_suf-2-02-2014-03-00529-0-000000606             Maybe
# 33  2014  sjmm_suf-2-02-2014-03-00818-0-000001257             Maybe
# 34  2014  sjmm_suf-2-02-2014-03-00839-0-000003065             Maybe
# 35  2014  sjmm_suf-2-02-2014-03-00877-0-000003097             Maybe
# 36  2014  sjmm_suf-2-02-2014-03-00881-0-000003203             Maybe
# 37  2014  sjmm_suf-2-02-2014-03-00901-0-000001081             Maybe
# 39  2014  sjmm_suf-2-02-2014-03-00907-0-000002630             Maybe
# 40  2014  sjmm_suf-2-02-2014-03-00913-0-000003847             Maybe
# 41  2014  sjmm_suf-2-02-2014-03-00995-0-000001242             Maybe
# 42  2014  sjmm_suf-2-02-2014-03-01057-0-000000376             Maybe
# 43  2014  sjmm_suf-2-02-2014-03-01074-0-000002306              True
# 44  2014  sjmm_suf-2-02-2014-03-01074-0-000002307              True
# 45  2014  sjmm_suf-2-02-2014-03-01074-0-000002308              True
# 46  2014  sjmm_suf-2-02-2014-03-01081-0-000003350             Maybe
# 47  2014  sjmm_suf-2-02-2014-03-01156-0-000002953             Maybe
# 50  2014  sjmm_suf-2-02-2014-03-01164-0-000003233             Maybe
# 51  2014  sjmm_suf-2-02-2014-03-01182-0-000002312             Maybe
# 52  2014  sjmm_suf-2-02-2014-03-01197-0-000003875             Maybe
# 53  2014  sjmm_suf-2-02-2014-03-01205-0-000001267             Maybe
# 54  2014  sjmm_suf-2-02-2014-03-01211-0-000002855             Maybe
# 55  2014  sjmm_suf-2-02-2014-03-01226-0-000001259             Maybe
# 56  2014  sjmm_suf-2-02-2014-03-01256-0-000002350             Maybe
# 57  2014  sjmm_suf-2-02-2014-03-01263-0-000001513             Maybe
# 58  2014  sjmm_suf-2-02-2014-03-01265-0-000002358             Maybe
# 59  2014  sjmm_suf-2-02-2014-03-01321-0-000000173             Maybe
# 60  2014  sjmm_suf-2-02-2014-03-01338-0-000001931             Maybe
# 61  2014  sjmm_suf-2-02-2014-03-01342-0-000000837             Maybe
#
#    ai_requirement_v7_rerun                                          reason_v7  \
# 0                    False  Role lists KNX Anlagen (building automation) —...
# 1                    False  Only CNC Kenntnisse (automation/machine contro...
# 2                    False  Mentions "moderne Steuerungstechnik" (general ...
# 4                     True  Mentions 'Optimierung der Prozesse' — general ...
# 5                    False  Requires control/automation skills (Steuertech...
# 6                    False  Role requires control/programming and monitori...
# 7                    False  Mentions 'Teilautomatisation' and 'Optimieren ...
# 8                    False  Mentions Gebäudeautomation and Steuerungen — a...
# 11                    True  Role includes 'laufende Optimierung unserer Pr...
# 12                   False  Role requires robotics/mechatronics expertise ...
# 13                   False  Mentions automation: 'Automatiker' and 'automa...
# 14                   False  Mentions automation (AUTOMATIKER EFZ, automati...
# 15                   False  Role requests 'Antriebs- und Automatisierungst...
# 16                   False  Mentions 'Bildverarbeitung' (image processing/...
# 17                   False  Role mentions optimization of test procedures/...
# 18                   False  Role requires experience with Automatisierungs...
# 20                   False  Role mentions test automation (Automatisierung...
# 21                   False  Mentions KNX (building/general automation) — a...
# 23                   False  Mentions "optimisation des processus orientés ...
# 25                   False  Role mentions optimizing parts and creating a ...
# 26                   False  Job requires experience with 'Yield Management...
# 27                   False  Role explicitly mentions optimization of syste...
# 29                   False  Role requires scripting to automate workflows ...
# 30                   False  Mentions L'optimisation des processus and data...
# 33                   False  Includes 'Automatiker EFZ' (automation role) w...
# 34                   False  Role includes commissioning of robots (robotic...
# 35                   False  Role requires Anlagensteuerung and Regelungste...
# 36                   False  Role requires Gebäudeautomation (building auto...
# 37                   False  Mentions automated and system‑supported prepre...
# 39                   False  Role includes Erstellung von Prognosen and ana...
# 40                   False  Role includes "Sales and Finance forecasting" ...
# 41                   False  Mentions modern control systems (Leittechnik) ...
# 42                   False  Role focuses on general automation (Automatisi...
# 43                   Maybe  Job states use of 'Spracherkennung' (speech re...
# 44                   Maybe  Job lists 'Spracherkennung' (speech recognitio...
# 45                   False  Role uses Spracherkennung (speech recognition)...
# 46                   False  Role involves automation/control systems (S7, ...
# 47                   False  Mentions optimization of skill-/grade-mix and ...
# 50                   False  Mentions KUKA-Roboterzelle and CNC-controlled ...
# 51                   False  Mentions Prozessoptimierung, Hochrechnungen an...
# 52                   False  Role uses Prozessleitsystem and mentions Betri...
# 53                   False  Role cites affinity to technical products in a...
# 54                   False  Role involves operating computer-controlled (a...
# 55                   False  Mentions Kuka-Roboter (robotics/robot control)...
# 56                   False  Role mentions automation of IT processes (gene...
# 57                   False  Role involves operating computer-controlled ma...
# 58                   False  Role mentions building automation and "digital...
# 59                   False  Role is an automation mechanic (automatik) inv...
# 60                    True  Mentions computer-controlled production equipm...
# 61                   False  Job cites automation, signal/control systems a...
#
#                                       reason_v7_rerun  \
# 0   This is a job advertisement for an electrician...
# 1   The provided text is a complete job advertisem...
# 2   This is a municipal job advertisement in Germa...
# 4   Das Dokument ist eine Stellenanzeige (Produkti...
# 5   This is a standard job advertisement in German...
# 6   This is a routine job advertisement for an ele...
# 7   The user provided a job advertisement text but...
# 8   Der eingegebene Text ist eine vollständige Ste...
# 11  Text is a job advertisement (position: Leitung...
# 12  This is a standard job advertisement in German...
# 13  This is a standard job advertisement (Servicet...
# 14  This is a straightforward job/apprenticeship a...
# 15  Die Stellenanzeige fordert keine Kenntnisse in...
# 16  This is a job advertisement text provided with...
# 17  This is a public job advertisement for a compa...
# 18  The ad contains no mention of artificial intel...
# 20  This is a standard job advertisement for a Tes...
# 21  This is a job ad for a Servicemonteur / Elektr...
# 23  The user pasted a job advertisement in French ...
# 25  This is a standard public job advertisement co...
# 26  This is a standard job advertisement (Assistan...
# 27  Die Stellenausschreibung fokussiert auf Unix/L...
# 29  This is a standard job advertisement describin...
# 30  L'offre concerne un poste d'analyste métier / ...
# 33  This is a listing of vocational apprenticeship...
# 34  Stellenanzeige für Einrichter/CNC-Rundtaktmasc...
# 35  The text is a job advertisement for an Elektro...
# 36  The job is for an application technician in el...
# 37  This is a standard German-language job adverti...
# 39  The job is a financial controlling/ reporting ...
# 40  This is a standard job advertisement containin...
# 41  The job ad is for a project manager/group lead...
# 42  This is a standard public job advertisement fo...
# 43  The user pasted a job advertisement but did no...
# 44  The ad does not explicitly request AI or machi...
# 45  This is a straightforward job advertisement wi...
# 46  The job ad is for an in‑house/in‑field commiss...
# 47  This is a clinical nursing leadership job (dep...
# 50  The text is a straightforward job advertisemen...
# 51  This is a standard job advertisement for a Con...
# 52  The job is for an operational/process plant op...
# 53  The submitted text is a job advertisement (inf...
# 54  The user provided an informational job/apprent...
# 55  This text is a job advertisement for CNC-Mecha...
# 56  The job is an IT Project Manager role focused ...
# 57  This is a harmless German apprenticeship/job p...
# 58  The text is a standard job advertisement in Ge...
# 59  The job ad describes hands-on electrical/autom...
# 60  The text is a recruitment/job advertisement fo...
# 61  Der Text ist eine Stellenanzeige (Betriebselek...
#
#                                           keywords_v7  \
# 0                                       [KNX Anlagen]
# 1                                    [CNC Kenntnisse]
# 2                         [moderne Steuerungstechnik]
# 4                          [Optimierung der Prozesse]
# 5   [Steuertechnik, Antriebstechnik, Regeltechnik,...
# 6   [Erfahrung in Steuerung und Programmierung und...
# 7   [Teilautomatisation, Optimieren von Produktion...
# 8                    [Gebäudeautomation, Steuerungen]
# 11            [laufende Optimierung unserer Prozesse]
# 12  [Robotik, Robotics, SCARA, 6-Achs Knickarmrobo...
# 13    [automatisierte HighTech-Lösungen, Automatiker]
# 14  [AUTOMATIKER EFZ, automatisierte Hightech-Lösu...
# 15  [Antriebs- und Automatisierungstechnik, Mechat...
# 16                                 [Bildverarbeitung]
# 17  [Weiterentwicklung _ und\nOptimierung _ von _ ...
# 18  [Automatisierungssysteme, Automatisierungssyst...
# 20  [Automatisierung im Testing, Testautomatisierung]
# 21                                   [SINA, UKV, KNX]
# 23  [optimisation des processus orientés clients (...
# 25                         [optimieren, Nesting-Plan]
# 26                                 [Yield Management]
# 27  [Optimierung von Systemkomponenten, Optimierun...
# 29  [Erstellen von Scripts zur Automatisierung von...
# 30  [L'optimisation des processus, analysez les Se...
# 33                                  [Automatiker EFZ]
# 34                                          [Roboter]
# 35               [Anlagensteuerung, Regelungstechnik]
# 36  [Gebäudeautomation, KNX, DALI, digitalStrom, E...
# 37  [automatisierten Seitenherstellung, systemgest...
# 39               [Prognosen, Analysen, Datenqualität]
# 40  [Sales and Finance forecasting, customer insig...
# 41           [Leittechnik, vernetzte Zutrittssysteme]
# 42  [Automatisierungstechnik, EMSR-Technik für pro...
# 43                                  [Spracherkennung]
# 44                                  [Spracherkennung]
# 45                                  [Spracherkennung]
# 46  [vollautomatischen Lager-, Förder- und Handlin...
# 47  [Optimierung des Skill- und Grademixes, Strukt...
# 50  [KUKA-Roboterzelle, CNC-gesteuerten Maschinen,...
# 51  [Prozessoptimierung, Hochrechnungen, Datenmana...
# 52              [Prozessleitsystem, Betriebsanalytik]
# 53                           [Automatisierungsumfeld]
# 54                       [computergesteuerte Anlagen]
# 55                                     [Kuka-Roboter]
# 56                  [Automatisierung der IT Prozesse]
# 57  [Computer gesteuerte Maschinen bedienen, Produ...
# 58  [Gebäudeautomation, digitale Regel-, Steuer- u...
# 59  [Automatikmonteur/in EFZ, AutomatikmonteurIn EFZ]
# 60           [computergesteuerten Produktionsanlagen]
# 61  [Signal-, Steuer- und Regeltechnik, Automatisi...
#
#                                     keywords_v7_rerun
# 0   [Elektroinstallateur/in EFZ, jung, selbständig...
# 1   [Gruppenleiter, Schreinerei, RWD Schlatter, Tü...
# 2   [Stellenanzeige, Mitarbeiter ARA, stellvertret...
# 4   [Produktionsleiter, Chemieingenieur, Pharmazeu...
# 5   [Betriebselektriker, Jobanzeige, Serge Ferrari...
# 6   [job ad, Elektrofachmann, Flughafen Zürich, Mi...
# 7   [Giessereitechnologen, stellvertretender Leite...
# 8   [Stellenanzeige, Spitaltechniker, Betriebselek...
# 11  [Leitung Hauswirtschaft, 100%, Alterswohnheim ...
# 12  [Applikationsingenieur Robotik, Stäubli, Horge...
# 13  [Servicetechniker, Polymechaniker, Automatiker...
# 14  [Logistiker EFZ, Lehrstellen 2014, Stäubli Sar...
# 15  [Verkaufsverantwortliche/r Systemverkauf, Regi...
# 16  [Produkt Manager, Automations-Spezialist, Auto...
# 17  [job advertisement, company, contact email pla...
# 18                                                 []
# 20  [job advertisement, Testmanager, Testing, soft...
# 21  [Servicemonteur, Elektroinstallateur, Starkstr...
# 23  [offre d'emploi, Responsable team révisions, S...
# 25  [Polymechaniker, CNC, Chiron MPS 08, Stans, Pi...
# 26  [Job advertisement, Assistant Front Desk Manag...
# 27  [Unix, Linux, Red Hat Enterprise Linux, Solari...
# 29  [Performance-Tester, Software-Ingenieur, Testm...
# 30  [Business Analyst, Spécialist achats, pharmaci...
# 33  [Lehrstellen, Flumroc AG, Pamag Engineering, L...
# 34  [Einrichter, CNC-Rundtaktmaschinen, Zerspanung...
# 35  [Stellenanzeige, Elektroingenieur, Elektrotech...
# 36  [Gebäudeautomation, Elektroinstallation, Niede...
# 37  [Teamleiter/in, Medienvorstufe, Stämpfli AG, Z...
# 39  [Controller, Division Reporting, Controlling, ...
# 40  [job ad, Pfizer, Country Brand Leader Switzerl...
# 41  [Projektleiter, Gruppenchef, Zutrittssysteme, ...
# 42  [Ingenieur, Techniker, Automatisierungstechnik...
# 43  [Leitende med. Praxisassistentin, Arztsekretär...
# 44  [RIS, PACS, Spracherkennung, MR-Technologie, v...
# 45  [Fachperson für med.-techn. Radiologie, Spring...
# 46  [Inbetriebnehmer, Servicetechniker, Fördertech...
# 47  [Chirurgie, Stv. Stationsleitung, Pflegefachpe...
# 50  [Stellenanzeige, Jobangebot, Einrichter, Mecha...
# 51  [Controller, Controlling, SAP, FI, CO, Busines...
# 52  [Heizwerkführer, Klärschlammverwertung, Schlam...
# 53  [job advertisement, Senior Marketing Manager, ...
# 54  [Chemie- und Pharmatechnologe, Pharmatechnolog...
# 55  [Job advertisement, CNC-Mechaniker, Polymechan...
# 56  [IT Project Manager, Customer Integration, eCo...
# 57  [Lehrstelle, Produktionsmechaniker, SFS servic...
# 58  [Jobanzeige, Gebäudeautomation, Projektleiter,...
# 59  [elektrische Steuerungen, Energieverteilungen,...
# 60  [job ad, recruitment, apprenticeship, Lehrstel...
# 61  [Stellenanzeige, Betriebselektriker, Vals, Coc...
