# %% [markdown]
# # Compare v7 vs v7 rerun
#
# Quick checks of label deltas between the original v7 run and the v7 rerun (2010–2024).

# %%
from pathlib import Path
import json
import pandas as pd

# Compute project root robustly for notebooks (no __file__)
def get_root() -> Path:
    p = Path.cwd()
    # Walk up until we find the marker folder
    for _ in range(5):
        if (p / "Results Datasets").exists():
            return p
        p = p.parent
    return Path.cwd()

ROOT = get_root()
RES_DIR = ROOT / "Results Datasets" / "ai_mentions" / "results" / "requirements"
V7_DIR = RES_DIR / "v7"
V7_RERUN = RES_DIR / "v7_rerun" / "ai_job_requirements_all_2010_2024_v7_rerun.json"

def load_results(path: Path) -> pd.DataFrame:
    data = json.loads(path.read_text(encoding="utf-8"))
    rows = []
    for y_str, ads in data.items():
        try:
            year = int(y_str)
        except Exception:
            continue
        for ad_id, payload in (ads or {}).items():
            rows.append(
                {
                    "year": year,
                    "ad_id": ad_id,
                    "ai_requirement": str(payload.get("ai_requirement", "False")).capitalize(),
                    "reason": payload.get("reason", ""),
                    "keywords": payload.get("keywords", []),
                }
            )
    return pd.DataFrame(rows)

def load_v7_all() -> pd.DataFrame:
    frames = []
    for p in sorted(V7_DIR.glob("ai_job_requirements_all_*_v7.json")):
        try:
            frames.append(load_results(p))
        except Exception:
            continue
    if not frames:
        return pd.DataFrame(columns=["year", "ad_id", "ai_requirement", "reason", "keywords"])
    df = pd.concat(frames, ignore_index=True)
    return df.drop_duplicates(subset=["year", "ad_id"], keep="last")

def load_v7_rerun() -> pd.DataFrame:
    if not V7_RERUN.exists():
        return pd.DataFrame(columns=["year", "ad_id", "ai_requirement", "reason", "keywords"])
    return load_results(V7_RERUN)

v7_df = load_v7_all()
v7r_df = load_v7_rerun()

v7_df = v7_df.rename(columns={
    "ai_requirement": "ai_requirement_v7",
    "reason": "reason_v7",
    "keywords": "keywords_v7",
})
v7r_df = v7r_df.rename(columns={
    "ai_requirement": "ai_requirement_v7_rerun",
    "reason": "reason_v7_rerun",
    "keywords": "keywords_v7_rerun",
})

df = v7_df.merge(v7r_df, on=["year", "ad_id"], how="outer")
df.head()

print(f"rows v7: {len(v7_df):,}")
print(f"rows v7 rerun: {len(v7r_df):,}")
print(f"merged rows: {len(df):,}")
# Out:
# rows v7: 57,280
# rows v7 rerun: 3,275
# merged rows: 57,280

# %%
# Overall contingency table
overall = df.pivot_table(
    index="ai_requirement_v7",
    columns="ai_requirement_v7_rerun",
    values="ad_id",
    aggfunc="count",
    fill_value=0,
)
overall
# Out:
# ai_requirement_v7_rerun  False  Maybe  True
# ai_requirement_v7
# Maybe                      908   1913    32
# True                         8     15   399

# %%
# Per-year label counts per version
per_year = (
    df.melt(id_vars=["year", "ad_id"], value_vars=["ai_requirement_v7", "ai_requirement_v7_rerun"], var_name="version", value_name="label")
    .pivot_table(index=["year", "version"], columns="label", values="ad_id", aggfunc="count", fill_value=0)
    .sort_index()
)
per_year
# Out:
# label                         False  Maybe  True
# year version
# 2010 ai_requirement_v7         3705    156     2
#      ai_requirement_v7_rerun     44    109     5
# 2011 ai_requirement_v7         3776    170     4
#      ai_requirement_v7_rerun     63    107     4
# 2012 ai_requirement_v7         3776    213     7
#      ai_requirement_v7_rerun     73    139     8
# 2013 ai_requirement_v7         3816    167    10
#      ai_requirement_v7_rerun     53    113    11
# 2014 ai_requirement_v7         3311    134     7
#      ai_requirement_v7_rerun     54     82     5
# 2015 ai_requirement_v7         3220    152    13
#      ai_requirement_v7_rerun     49    101    15
# 2016 ai_requirement_v7         3525    176    12
#      ai_requirement_v7_rerun     57    119    12
# 2017 ai_requirement_v7         3433    215    25
#      ai_requirement_v7_rerun     72    144    24
# 2018 ai_requirement_v7         3580    213    32
#      ai_requirement_v7_rerun     64    151    30
# 2019 ai_requirement_v7         3715    230    48
#      ai_requirement_v7_rerun     63    165    50
# 2020 ai_requirement_v7         3599    217    39
#      ai_requirement_v7_rerun     69    150    37
# 2021 ai_requirement_v7         3673    232    62
#      ai_requirement_v7_rerun     72    163    59
# 2022 ai_requirement_v7         3629    233    60
#      ai_requirement_v7_rerun     78    153    62
# 2023 ai_requirement_v7         3551    119    42
#      ai_requirement_v7_rerun     29     83    49
# 2024 ai_requirement_v7         3696    226    59
#      ai_requirement_v7_rerun     76    149    60

# %%
# Flip summary and sample
flips = df[df["ai_requirement_v7"] != df["ai_requirement_v7_rerun"]].copy()
flip_counts = flips.groupby(["ai_requirement_v7", "ai_requirement_v7_rerun"]).size().reset_index(name="count")
flip_counts
# Out:
#   ai_requirement_v7 ai_requirement_v7_rerun  count
# 0             Maybe                   False    908
# 1             Maybe                    True     32
# 2              True                   False      8
# 3              True                   Maybe     15

# %%
flips_sample = flips.head(50)[[
    "year", "ad_id", "ai_requirement_v7", "ai_requirement_v7_rerun", "reason_v7", "reason_v7_rerun", "keywords_v7", "keywords_v7_rerun"
]]
flips_sample
# Out:
#     year                                    ad_id ai_requirement_v7  \
# 0   2010  sjmm_suf-1-01-2010-03-01118-0-000000001             False
# 1   2010  sjmm_suf-1-01-2010-03-01118-0-000000002             False
# 2   2010  sjmm_suf-1-01-2010-03-01119-0-000000001             False
# 3   2010  sjmm_suf-1-01-2010-03-01120-0-000000001             False
# 4   2010  sjmm_suf-1-01-2010-03-01120-0-000000002             False
# 5   2010  sjmm_suf-1-01-2010-03-01120-0-000000003             False
# 6   2010  sjmm_suf-1-01-2010-03-01120-0-000000004             False
# 7   2010  sjmm_suf-1-01-2010-03-01120-0-000000005             False
# 8   2010  sjmm_suf-1-01-2010-03-01120-0-000000006             False
# 9   2010  sjmm_suf-1-01-2010-03-01120-0-000000007             False
# 11  2010  sjmm_suf-1-01-2010-03-01120-0-000000009             False
# 12  2010  sjmm_suf-1-01-2010-03-01120-0-000000010             False
# 13  2010  sjmm_suf-1-01-2010-03-01120-0-000000011             False
# 14  2010  sjmm_suf-1-01-2010-03-01120-0-000000012             False
# 15  2010  sjmm_suf-1-01-2010-03-01120-0-000000013             False
# 16  2010  sjmm_suf-1-01-2010-03-01208-0-000000001             False
# 17  2010  sjmm_suf-1-01-2010-03-01208-0-000000002             False
# 18  2010  sjmm_suf-1-01-2010-03-01208-0-000000003             False
# 19  2010  sjmm_suf-1-01-2010-03-01210-0-000000001             False
     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 19                     NaN  No AI/ML terms or AI-adjacent skills; role foc...
# 20                     NaN  No AI/ML or AI-adjacent skills mentioned; only...
# 21                     NaN  No AI/ML terms or AI-adjacent skills mentioned...
# 22                     NaN  No AI/ML or AI-adjacent skills mentioned in ro...
# 23                     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 24                     NaN  No AI/ML mentions; role is a sales/customer-fa...
# 25                     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 26                     NaN  No AI/ML terms; only general IT/MS-Office and ...
# 27                     NaN  No AI/ML terms; role focuses on web/print desi...
# 28                     NaN  No AI/ML or AI-adjacent skills mentioned in th...
# 29                     NaN  No AI/ML or AI-adjacent skills, tools, or resp...
# 30                     NaN  No AI/ML terms or AI-adjacent requirements; ro...
# 31                     NaN  No explicit AI/ML skills or responsibilities m...
# 32                     NaN  No AI/ML terms; only general IT ("Gute EDVKenn...
# 33                     NaN  No AI/ML or AI-adjacent skills or tools are me...
# 34                     NaN  No AI/ML terms or AI-adjacent requirements; fi...
# 35                     NaN  No AI/ML terms or AI-adjacent skills mentioned...
# 36                     NaN  No AI/ML terms or AI-adjacent skills in the jo...
# 37                     NaN  No AI/ML mention; role focuses on Moodle eLear...
# 38                     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 39                     NaN  No AI/ML-related skills or tools mentioned; on...
# 40                     NaN  No AI/ML terms; role focuses on electrical eng...
# 41                     NaN  No AI/ML or AI-adjacent terms; primary school ...
# 42                     NaN  No AI/ML terms or AI-adjacent skills mentioned...
# 43                     NaN  No AI/ML or AI-adjacent skills mentioned (offi...
# 44                     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 45                     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 46                     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 47                     NaN  No AI/ML terms present; role is office, sales ...
# 48                     NaN  No AI/ML or AI-adjacent skills mentioned; role...
# 49                     NaN  No AI/ML or AI-adjacent skills mentioned; it's...
# 50                     NaN  No AI/ML mentions; only basic EDV skills (Word...
#
#    reason_v7_rerun keywords_v7 keywords_v7_rerun
# 0              NaN          []               NaN
# 1              NaN          []               NaN
# 2              NaN          []               NaN
# 3              NaN          []               NaN
# 4              NaN          []               NaN
# 5              NaN          []               NaN
# 6              NaN          []               NaN
# 7              NaN          []               NaN
# 8              NaN          []               NaN
# 9              NaN          []               NaN
# 11             NaN          []               NaN
# 12             NaN          []               NaN
# 13             NaN          []               NaN
# 14             NaN          []               NaN
# 15             NaN          []               NaN
# 16             NaN          []               NaN
# 17             NaN          []               NaN
# 18             NaN          []               NaN
# 19             NaN          []               NaN
# 20             NaN          []               NaN
# 21             NaN          []               NaN
# 22             NaN          []               NaN
# 23             NaN          []               NaN
# 24             NaN          []               NaN
# 25             NaN          []               NaN
# 26             NaN          []               NaN
# 27             NaN          []               NaN
# 28             NaN          []               NaN
# 29             NaN          []               NaN
# 30             NaN          []               NaN
# 31             NaN          []               NaN
# 32             NaN          []               NaN
# 33             NaN          []               NaN
# 34             NaN          []               NaN
# 35             NaN          []               NaN
# 36             NaN          []               NaN
# 37             NaN          []               NaN
# 38             NaN          []               NaN
# 39             NaN          []               NaN
# 40             NaN          []               NaN
# 41             NaN          []               NaN
# 42             NaN          []               NaN
# 43             NaN          []               NaN
# 44             NaN          []               NaN
# 45             NaN          []               NaN
# 46             NaN          []               NaN
# 47             NaN          []               NaN
# 48             NaN          []               NaN
# 49             NaN          []               NaN
# 50             NaN          []               NaN
