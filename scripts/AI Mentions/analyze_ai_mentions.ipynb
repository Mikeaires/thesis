# %% [markdown]
# # AI Mentions — Exploration
# This notebook inspects the output from `scripts/detect_ai_mentions.py` (stored at `Results Datasets/exposures/ai_keyword_matches.json`) and visualizes how AI mentions are distributed over time and by source (ICT vs EDU).

# %%
from pathlib import Path
import json
import pandas as pd
import matplotlib.pyplot as plt
# seaborn optional
try:
    import seaborn as sns
    sns.set_context('talk')
except Exception:
    sns = None

ROOT = Path.cwd().parents[0]
MATCH_PATH = ROOT / 'Results Datasets' / 'exposures' / 'ai_keyword_matches.json'
print('Reading', MATCH_PATH)
data = json.loads(MATCH_PATH.read_text(encoding='utf-8'))
len(data)
# Out:
# Reading /Users/miguel/Documents/Master Thesis/Thesis/Results Datasets/exposures/ai_keyword_matches.json
# 25

# %%
# Flatten year → ad → matches into a tabular frame
rows = []
for year, ads in data.items():
    for ad_id, matches in ads.items():
        for m in matches:
            rows.append({
                'year': int(year),
                'ad_id': ad_id,
                'folder': m.get('folder'),
                'keyword': m.get('keyword'),
                'text': m.get('text', '')
            })
df = pd.DataFrame(rows)
df.sort_values(by='year')
# Out:
#      year                                    ad_id folder  \
# 624  1992  sjmm_suf-1-01-1992-03-02102-0-000000097    edu
# 623  1992  sjmm_suf-1-01-1992-03-02102-0-000000097    edu
# 621  1992  sjmm_suf-1-01-1992-03-03108-0-000000001    edu
# 622  1992  sjmm_suf-1-01-1992-03-03108-0-000000001    edu
# 0    1995  sjmm_suf-1-01-1995-03-05203-0-000000016    ict
# ..    ...                                      ...    ...
# 539  2024  sjmm_suf-2-05-2024-03-05722-1-000365579    ict
# 540  2024  sjmm_suf-2-05-2024-03-05722-1-000365579    ict
# 541  2024  sjmm_suf-2-05-2024-03-05722-1-000365579    ict
# 535  2024  sjmm_suf-2-05-2024-03-05722-1-000365579    ict
# 496  2024  sjmm_suf-2-05-2024-03-06226-1-000355694    ict
#
#                     keyword                                               text
# 624                      ki                               kirchenmusikalischem
# 623                      ki  Erfahrung auf kirchenmusikalischem und allgeme...
# 621                      ai  guten Kenntnissen der Ostschweizer Verhältniss...
# 622                      ai                                                 AI
# 0              dialogsystem                                       Dialogsystem
# ..                      ...                                                ...
# 539                      ai                                                 AI
# 540                      ai                                    AI-Technologien
# 541                      ai                                     AI-Initiativen
# 535                      ai                                                 AI
# 496  künstliche intelligenz                             künstliche Intelligenz
#
# [630 rows x 5 columns]

# %%
df['keyword'].value_counts()
# Out:
# keyword
# ai                             87
# ki                             80
# robotik                        73
# machine learning               56
# data mining                    35
# bildverarbeitung               34
# robotics                       26
# spracherkennung                22
# artificial intelligence        19
# künstliche intelligenz         18
# ml                             14
# advanced analytics             14
# jax                            12
# nlp                            11
# deep learning                  10
# tensorflow                     10
# maschinelles lernen            10
# predictive analytics            7
# keras                           6
# natural language processing     6
# predictive maintenance          6
# airflow                         6
# mlops                           6
# ray                             4
# svm                             4
# computer vision                 3
# mdp                             3
# spacy                           3
# scikit-learn                    3
# algorithmus-entwicklung         3
# gan                             3
# topic modeling                  3
# opencv                          3
# apache airflow                  3
# textanalyse                     3
# anomaly detection               2
# predictive modeling             2
# conversational ai               2
# text analytics                  2
# text mining                     2
# chatbots                        2
# chatbot                         2
# chatgpt                         1
# recommender systems             1
# decision trees                  1
# fine-tuning                     1
# neuronale netze                 1
# lineare regression              1
# objekterkennung                 1
# llm                             1
# ner                             1
# dialogsystem                    1
# Name: count, dtype: int64

# %%
# Basic overview
total_ads_with_matches = df['ad_id'].nunique()
total_mentions = len(df)
unique_keywords = df['keyword'].nunique()
print(f'Ads with ≥1 match: {total_ads_with_matches:,}')
print(f'Total keyword mentions: {total_mentions:,}')
print(f'Unique keywords matched: {unique_keywords}')
print(df['folder'].value_counts())
# Out:
# Ads with ≥1 match: 221
# Total keyword mentions: 630
# Unique keywords matched: 52
# folder
# edu    318
# ict    312
# Name: count, dtype: int64

# %%
# Mentions per year
per_year = df.groupby('year').size().rename('mentions').reset_index()
per_year_folder = df.groupby(['year','folder']).size().rename('mentions').reset_index()
ax = per_year.plot(x='year', y='mentions', figsize=(10,4), title='AI mentions per year')
ax.set_xlabel('Year'); ax.set_ylabel('Mentions'); plt.show()
if sns is not None:
    plt.figure(figsize=(10,4))
    sns.lineplot(data=per_year_folder, x='year', y='mentions', hue='folder')
    plt.title('AI mentions per year by source (ICT vs EDU)')
    plt.show()

# %%
a = df.query("keyword == 'ai'")[['year','text']]
for x in a.itertuples():
    print(x.year, x.text)
# Out:
# 2015 Erfahrung im Langstreckeneinsatz und auf «wide body aircraft»
# 2015 wide body aircraft
# 2019 AI
# 2020 AI
# 2021 Master universitaire en sciences humaines ou formation jugee equivalente complete par un Master en sante publique.
# Specialisation en management, management des institutions de sante, en sante publique, en organisation et/ou en gestion de projet, maitrise de la langue anglaise.
# Solide experience dans la direction d'une institution de sante et/ou sante publique. Experience en gestion d'equipes. Direction d'une structure publique ou privee pendant une periode d'au moins 5 ans
# Vos avantages
# Le DIP a pour mission, notamment, de donner a chaque eleve le moyen d'acquerir les meilleures connaissances et competences en vue de ses activites futures, et de chercher a susciter chez lui le desir d'apprendre et de se former, ceci en l'aidant a developper ses aptitudes et affermir son sens des responsabilites. En outre, le DIP veille au bien-etre, a la protection, a la sante et a la securite des enfants et adolescents.
# En integrant l'un de nos offices/etablissements/services, quelle que soit la fonction, vous concourrez a la realisation de ces missions.
# Da das DIP die Arbeit von mehr als 9.000 Mitarbeitern vereint, treten Sie auch der grössten Abteilung des Bundesstaates Genf bei, die reich an der daraus resultierenden Vielfalt ist und in der die oben genannten Verpflichtungen Ihre eigene berufliche Entwicklung unterstützen.
# Schliesslich profitieren Sie von hochwertigen sozialen Diensten, einem grossen und vielfältigen Weiterbildungsangebot und von Entwicklungsmöglichkeiten während Ihrer gesamten Karriere.
# Beobachtungen
# 	Drucken Sie dieses Angebot aus
# Teile diese Seite
#
# Dunkles Fusszeilenmenü
# Geschäftsbedingungen
# Übersetzung
# Telefonbuch
# Staatliches Intranet
# GE.CH - Republik und Kanton Genf
#
# 2021 Master en Informatique ou titre equivalent ;
# 	Minimum 5 ans d'experience ;
# 	Experience en scripting, IT automation ;
# 	Experience et mindset « developpeur » (rediger et suivre des specifications, tests unitaires, versioning, documentation) ;
# 	Capacite de supervision et coordination ;
# 	Responsabilite, rigueur, polyvalence, autonomie, curiosite, esprit d'equipe et aisance relationnelle ;
# 	Maitrise du francais et anglais ;
# 	Domicilie/e en Suisse.
# 	Si vous vous reconnaissez dans cette description, nous nous rejouissons de recevoir votre dossier, qui sera traite avec la plus stricte confidentialite.
# 	Wenn diese Beschreibung auf Sie zutrifft, zögern Sie nicht - senden Sie uns Ihre Bewerbung. Wir freuen uns darauf, Sie kennenzulernen.
# 	Vor mehr als 30 Tagen ausgeschrieben
# 	Full time
# 	R0001285
# Über uns
# 	Helfen Sie uns, die Bank von morgen aufzubauen. Das Ziel von Lombard Odier ist es, das Vermögen unserer Kunden zu erhalten und zu mehren. Seit über 220 Jahren geniessen wir das Vertrauen unserer Kunden. Während sieben Generationen haben wir 40 Finanzkrisen überstanden und unablässig Innovationen hervorgebracht, um unseren Kunden mit erstklassigen und nachhaltigen Lösungen dienen zu können.
# 	Unsere Mission für Sie.
# 	Lombard Odier ist ein Arbeitgeber erster Wahl. Unser Ziel ist es, unseren Mitarbeiterinnen und Mitarbeitern ein anregendes Arbeitsumfeld zu bieten, das Kreativität und Innovation fördert. So möchten wir sie dazu ermutigen, neue Geschäftschancen zu nutzen und effizienter zu arbeiten.
# 	Unsere Unternehmenskultur.
# 	Bei Lombard Odier wissen wir, dass unsere Mitarbeitenden eine kostbare Ressource sind. Deshalb haben wir ein Klima geschaffen, in dem sich jeder individuell entfalten und zusammen mit den anderen an der Umsetzung unserer Ziele arbeiten kann. Im Zentrum unserer Unternehmenskultur steht die Gestaltung eines positiven und dynamischen Arbeitsumfelds, das unsere Teams inspiriert, Bestehendes fortlaufend zu hinterfragen und nach neuen Lösungen zu suchen.
# 	Diversität und Inklusion.
# 	Wir sehen uns als Arbeitgeber der Chancengleichheit verpflichtet. Als EDGE (Economic Dividends for Gender Equality) zertifizierte Organisation sind wir bestrebt, einen optimalen Arbeitsplatz für Frauen und Männer zu schaffen, der sie zu ausserordentlichen Leistungen beflügelt. EDGE ist der führende globale Standard zur Bewertung der Geschlechtergleichstellung am Arbeitsplatz.
# 	Weiterbildung.
# 	Wenn unsere Mitarbeiterinnen und Mitarbeiter besser werden, wird auch unser Unternehmen besser. Daher unterstützen wir bei Lombard Odier unsere Mitarbeitenden dabei, Verantwortung für ihre persönliche und berufliche Entwicklung zu übernehmen. Dabei ist es unser Ziel, unter Berücksichtigung unserer Unternehmenswerte die Talente jedes einzelnen Mitarbeitenden zu erkennen und zu fördern. Unser vielfältiges und hochwertiges Ausbildungsangebot ist Ausdruck unsere Wertschätzung der Kompetenzen und Kenntnisse unserer Mitarbeitenden und ermöglicht deren Weiterentwicklung.
#
# 2021 Master universitaire ou titre equivalent ;
# 	Minimum 5 ans d'experience ;
# 	Comprehension des processus ITIL ;
# 	Bonne comprehension globale du fonctionnement d'une IT complexe ;
# 	Experience sur la plateforme ServiceNow est un plus ;
# 	Responsabilite, rigueur, polyvalence, autonomie, curiosite, esprit d'equipe et aisance relationnelle ;
# 	Maitrise du francais et anglais ;
# 	Domicilie/e en Suisse.
# 	Si vous vous reconnaissez dans cette description, nous nous rejouissons de recevoir votre dossier, qui sera traite avec la plus stricte confidentialite.
# 	Wenn diese Beschreibung auf Sie zutrifft, zögern Sie nicht - senden Sie uns Ihre Bewerbung. Wir freuen uns darauf, Sie kennenzulernen.
# 	Vor mehr als 30 Tagen ausgeschrieben
# 	Full time
# 	R0001286
# Über uns
# 	Helfen Sie uns, die Bank von morgen aufzubauen. Das Ziel von Lombard Odier ist es, das Vermögen unserer Kunden zu erhalten und zu mehren. Seit über 220 Jahren geniessen wir das Vertrauen unserer Kunden. Während sieben Generationen haben wir 40 Finanzkrisen überstanden und unablässig Innovationen hervorgebracht, um unseren Kunden mit erstklassigen und nachhaltigen Lösungen dienen zu können.
# 	Unsere Mission für Sie.
# 	Lombard Odier ist ein Arbeitgeber erster Wahl. Unser Ziel ist es, unseren Mitarbeiterinnen und Mitarbeitern ein anregendes Arbeitsumfeld zu bieten, das Kreativität und Innovation fördert. So möchten wir sie dazu ermutigen, neue Geschäftschancen zu nutzen und effizienter zu arbeiten.
# 	Unsere Unternehmenskultur.
# 	Bei Lombard Odier wissen wir, dass unsere Mitarbeitenden eine kostbare Ressource sind. Deshalb haben wir ein Klima geschaffen, in dem sich jeder individuell entfalten und zusammen mit den anderen an der Umsetzung unserer Ziele arbeiten kann. Im Zentrum unserer Unternehmenskultur steht die Gestaltung eines positiven und dynamischen Arbeitsumfelds, das unsere Teams inspiriert, Bestehendes fortlaufend zu hinterfragen und nach neuen Lösungen zu suchen.
# 	Diversität und Inklusion.
# 	Wir sehen uns als Arbeitgeber der Chancengleichheit verpflichtet. Als EDGE (Economic Dividends for Gender Equality) zertifizierte Organisation sind wir bestrebt, einen optimalen Arbeitsplatz für Frauen und Männer zu schaffen, der sie zu ausserordentlichen Leistungen beflügelt. EDGE ist der führende globale Standard zur Bewertung der Geschlechtergleichstellung am Arbeitsplatz.
# 	Weiterbildung.
# 	Wenn unsere Mitarbeiterinnen und Mitarbeiter besser werden, wird auch unser Unternehmen besser. Daher unterstützen wir bei Lombard Odier unsere Mitarbeitenden dabei, Verantwortung für ihre persönliche und berufliche Entwicklung zu übernehmen. Dabei ist es unser Ziel, unter Berücksichtigung unserer Unternehmenswerte die Talente jedes einzelnen Mitarbeitenden zu erkennen und zu fördern. Unser vielfältiges und hochwertiges Ausbildungsangebot ist Ausdruck unsere Wertschätzung der Kompetenzen und Kenntnisse unserer Mitarbeitenden und ermöglicht deren Weiterentwicklung.
#
# 2021 aisance relationnelle
# 2021 Master et/ou diplome d'expertise fiscale ou CSI III ou formation jugee equivalente, assortis de 5 ans d'experience dans le domaine de la fiscalite dans le secteur prive ou public ;
# Des connaissances approfondies en matiere de comptabilite et de droit fiscal suisse/international, confirmees par une formation continue permanente ;
# Une formation et une experience confirmee en gestion de projets ;
# Aisance dans les contacts humains et esprit d'equipe ;
# La pratique de l'allemand et/ou de l'anglais ecrit et oral est un atout.
# De par vos fonctions, vous devrez avoir une bonne faculte d'argumentation, un esprit de persuasion et demontrer une grande capacite d'analyse et de synthese. Vous devrez egalement faire preuve d'autonomie, d'adaptation et etre en mesure de gerer une charge de travail importante ainsi que la pression inherente aux enjeux des dossiers sur lesquels vous serez implique-e.
# Vous aimez collaborer, definir et partager des objectifs avec une equipe et etes interesse-e aux techniques de co-creation et d'intelligence collective.
# Vos avantages
# Vous travaillerez au sein d'une equipe solidaire de 15 personnes a un niveau strategique et occuperez un poste polyvalent et diversifie, tant dans la nature de ses activites que son rythme. De plus, vous serez en contact avec une grande diversite d'interlocuteurs.
# Sie profitieren auch von den Gehalts- und persönlichen Entwicklungsbedingungen des Staates Genf.
# Beobachtungen
# Da die Serviceangebote elektronisch verwaltet werden, danken wir Ihnen, dass Sie Ihre vollständige Datei (Anschreiben, Lebenslauf, Kopien von Diplomen und Arbeitgeberzertifikaten) über den Internetlink am Ende dieser Nachricht gesendet haben.
# Es werden nur Dateien berücksichtigt, die dem gewünschten Profil entsprechen, vollständig sind und rechtzeitig eingehen.
# Arbeitsplatz
# Hotel des finances
# Rue du Stand 26
# 1204 Genf
# 	Drucken Sie dieses Angebot aus
# Teile diese Seite
#
# Dunkles Fusszeilenmenü
# Geschäftsbedingungen
# Übersetzung
# Telefonbuch
# Staatliches Intranet
# GE.CH - Republik und Kanton Genf
# Durch das Surfen auf dieser Website akzeptieren Sie die statistische Verwendung von Cookies, die zur kontinuierlichen Verbesserung bestimmt sind. Mehr InformationenAkzeptieren
#
# 2021 charge de travail importante ainsi que la pression inherente aux enjeux des dossiers sur lesquels vous serez implique-e.
# Vous aimez collaborer, definir et partager des objectifs avec une equipe et etes interesse-e aux techniques de co-creation et d'intelligence collective
# 2022 AI Builder
# 2022 AI
# 2022 Kenntnisse von aktuellen Technologietrends (u.a Big Data/Machine Learning/AI, IoT, AR/VR, Blockchain, Cloud, Mobile) und deren Potential für Business-Innovation
# 2022 AI
# 2022 AI
# 2022 AI
# 2022 AI
# 2023 AI
# 2023 AI
#
# Data
# 2023 AI
# 2023 Applied Conversational AI
# 2023 Applied Conversational AI - Doktorandenstelle
# 2023 AI
# 2023 IoT, AI, Big Data, Analytics, Cloud und Digitalisierung in der Finanzindustrie
# 2023 AI
# 2023 BAV-Ausweis Kat. Ai40/A40/Ai/A.
# 2023 Ai/A.
# 2023 Abgeschlossene Ausbildung oder in Weiterbildung als Rangierbegleiter Ai/Ai40
# 2023 Rangierbegleiter Ai/Ai40
# 2024 AI
#
# IT Tools
# 2024 AI
#
# IT Tools
# 2024 Data Strategy Consultant
#
# Data & AI
# 2024 AI + Data Practice
# 2024 AI-Technologien
# 2024 AI-Projekten
# 2024 AI-Offering
# 2024 AI
# 2024 AI-Projekten
# 2024 AI
# 2024 AI-
# 2024 AI
# 2024 Data Strategy Consultant
#
# Data & AI
# 2024 AI + Data Practice
# 2024 AI-Technologien
# 2024 AI-Projekten
# 2024 AI-Offering
# 2024 AI
# 2024 AI-Projekten
# 2024 AI
# 2024 AI-
# 2024 AI
# 2024 verstehst AI- und Daten-Technologien als Werkzeuge, um faktenbasierte Entscheidungen zu ermöglichen, Prozesse zu optimieren oder neue Produkte und Dienstleistungen zu entwickeln. Damit erkennst Du bei unseren Kunden Potenziale, um mit diesen Werk-zeugen echten Wert für ihr Business zu generieren.
#
# Dein Profil:
#
# Du verfügst über ein Hochschulstudium im Bereich Business Management
# 2024 AI-
# 2024 Zusatzausbildung im Bereich AI
# 2024 AI
# 2024 verstehst AI- und Daten-Technologien als Werkzeuge, um faktenbasierte Entscheidungen zu ermöglichen, Prozesse zu optimieren oder neue Produkte und Dienstleistungen zu entwickeln. Damit erkennst Du bei unseren Kunden Potenziale, um mit diesen Werk-zeugen echten Wert für ihr Business zu generieren.
#
# Dein Profil:
#
# Du verfügst über ein Hochschulstudium im Bereich Business Management
# 2024 AI-
# 2024 Zusatzausbildung im Bereich AI
# 2024 AI
# 2024 AI
# 2024 AI-Initiativen
# 2024 AI
# 2024 AI-Community
# 2024 AI
# 2024 AI-Technologien
# 2024 AI-Initiativen
# 2024 AI
# 2024 AI
# 2024 AI
# 2024 AI-Initiativen
# 2024 AI
# 2024 AI-Community
# 2024 AI
# 2024 AI-Technologien
# 2024 AI-Initiativen
# 2024 AI
# 2024 AI
# 2024 AI
# 2024 AI
# 2024 AI
# 2024 AI
# 2024 VTE10, Ai oder höher
# 2024 Ai
# 2024 VTE10, Ai oder höher
# 2024 Ai
# 1992 guten Kenntnissen der Ostschweizer Verhältnisse (insb. SG, AI, AR)
# 1992 AI

# %%
# Top keywords overall and by source
top_kw = df['keyword'].value_counts().head(20)
print(top_kw)
if sns is not None:
    plt.figure(figsize=(8,6))
    sns.barplot(x=top_kw.values, y=top_kw.index, orient='h')
    plt.title('Top 20 keywords (overall)'); plt.xlabel('Mentions'); plt.ylabel('Keyword')
    plt.show()

top_by_src = (df.groupby(['folder','keyword']).size()
               .reset_index(name='mentions')
               .sort_values(['folder','mentions'], ascending=[True, False])
              )
top_by_src.head(20)
# Out:
# keyword
# ai                             87
# ki                             80
# robotik                        73
# machine learning               56
# data mining                    35
# bildverarbeitung               34
# robotics                       26
# spracherkennung                22
# artificial intelligence        19
# künstliche intelligenz         18
# ml                             14
# advanced analytics             14
# jax                            12
# nlp                            11
# deep learning                  10
# tensorflow                     10
# maschinelles lernen            10
# predictive analytics            7
# keras                           6
# natural language processing     6
# Name: count, dtype: int64
#    folder                      keyword  mentions
# 14    edu                           ki        68
# 30    edu                      robotik        44
# 1     edu                           ai        30
# 17    edu             machine learning        24
# 9     edu                  data mining        18
# 7     edu             bildverarbeitung        16
# 29    edu                     robotics        14
# 0     edu           advanced analytics         8
# 20    edu                           ml         8
# 12    edu                          jax         7
# 10    edu                deep learning         6
# 24    edu                          nlp         6
# 27    edu       predictive maintenance         6
# 35    edu                   tensorflow         6
# 2     edu                      airflow         4
# 6     edu      artificial intelligence         4
# 13    edu                        keras         4
# 18    edu          maschinelles lernen         4
# 21    edu                        mlops         4
# 22    edu  natural language processing         4

# %%
# (Optional) heatmap for top N keywords across years
N = 15
topN = df['keyword'].value_counts().head(N).index
heat = (df[df['keyword'].isin(topN)]
        .groupby(['year','keyword']).size()
        .unstack(fill_value=0)
       )
if sns is not None and len(heat)>0:
    plt.figure(figsize=(12,6))
    sns.heatmap(heat.T, cmap='viridis')
    plt.title(f'Mentions per year for top {N} keywords')
    plt.xlabel('Year'); plt.ylabel('Keyword')
    plt.show()
heat.tail()
# Out:
# keyword  advanced analytics  ai  artificial intelligence  bildverarbeitung  \
# year
# 2020                      3   1                        0                 4
# 2021                      5   6                        2                 1
# 2022                      0   7                        7                 2
# 2023                      0  12                        0                 3
# 2024                      0  56                        6                 6
#
# keyword  data mining  deep learning  jax  ki  künstliche intelligenz  \
# year
# 2020               5              3    0   9                       8
# 2021               3              0    1   5                       1
# 2022               3              0    0   0                       2
# 2023               0              0    0   8                       1
# 2024               0              0    0  22                       4
#
# keyword  machine learning  ml  nlp  robotics  robotik  spracherkennung
# year
# 2020                   15   0    0         0       10                1
# 2021                   13   0    2         4        3                3
# 2022                   11   0    0         2        6                1
# 2023                    0   4    0         0        9                0
# 2024                    0   8    0         0       14                0
