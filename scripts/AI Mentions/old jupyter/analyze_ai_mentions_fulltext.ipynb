# %% [markdown]
# # AI Mentions — Full Text Analysis
# This notebook analyzes matches produced by `scripts/detect_ai_mentions_fulltext.py` (scanning `adve_text_adve` from 2005 onward).

# %%
from pathlib import Path
import json
import pandas as pd
import matplotlib.pyplot as plt
try:
    import seaborn as sns; sns.set_context('talk')
except Exception:
    sns = None

ROOT = Path.cwd().parents[1]
MATCH_PATH = ROOT / 'Results Datasets' / 'ai_mentions' / 'ai_keyword_matches_fulltext.json'
print('Reading', MATCH_PATH)
data = json.loads(MATCH_PATH.read_text(encoding='utf-8'))
len(data)
# Out:
# Reading /Users/miguel/Documents/Master Thesis/Thesis/Results Datasets/ai_mentions/ai_keyword_matches_fulltext.json
# 15

# %%
len(df['ad_id'].unique())
# Out:
# 615

# %%
grouped_df = df.groupby('ad_id')[['keyword','snippet']].agg(tuple)
grouped_df = grouped_df.map(lambda x: tuple(set(x)))
grouped_df
# Out:
#                                                                                    keyword  \
# ad_id
# sjmm_suf-2-02-2020-03-00046-0-000002847                                         (robotik,)
# sjmm_suf-2-02-2020-03-00116-0-000003430  (nlp, reinforcement learning, collaborative fi...
# sjmm_suf-2-02-2020-03-00137-0-000004309                                         (robotik,)
# sjmm_suf-2-02-2020-03-00137-0-000004311                                         (robotik,)
# sjmm_suf-2-02-2020-03-00137-0-000004312                                         (robotik,)
# ...                                                                                    ...
# sjmm_suf-3-01-2024-03-09019-1-055826811            (machine learning, predictive modeling)
# sjmm_suf-3-01-2024-03-09019-1-055826855                                              (ai,)
# sjmm_suf-3-01-2024-03-09019-1-055842847                                (machine learning,)
# sjmm_suf-3-01-2024-03-09019-1-055842908    (artificial intelligence, machine learning, ai)
# sjmm_suf-3-01-2024-03-09020-1-055846996                                         (robotik,)
#
#                                                                                    snippet
# ad_id
# sjmm_suf-2-02-2020-03-00046-0-000002847  (schinen, Kupplungssysteme und «Robotik». Welt...
# sjmm_suf-2-02-2020-03-00116-0-000003430  (achine learning and federated «machine learni...
# sjmm_suf-2-02-2020-03-00137-0-000004309  (äte & Werkzeuge\nMechatronik & «Robotik»\nSof...
# sjmm_suf-2-02-2020-03-00137-0-000004311  (ojektleiter / Projektleiterin «Robotik»\n\nSt...
# sjmm_suf-2-02-2020-03-00137-0-000004312  (äte & Werkzeuge\nMechatronik & «Robotik»\nSof...
# ...                                                                                    ...
# sjmm_suf-3-01-2024-03-09019-1-055826811  (ologies (predictive modeling, «machine learni...
# sjmm_suf-3-01-2024-03-09019-1-055826855  (n using sensor technology and «AI» based algo...
# sjmm_suf-3-01-2024-03-09019-1-055842847  (ty to the ticketing business («machine learni...
# sjmm_suf-3-01-2024-03-09019-1-055842908  (with artificial intelligence («AI») and machi...
# sjmm_suf-3-01-2024-03-09020-1-055846996  (iven Produkten und modernster «Robotik» revol...
#
# [310 rows x 2 columns]

# %%
grouped_df_filtered = grouped_df[grouped_df['keyword'].map(lambda x: len(x)==1)].reset_index()
grouped_df_filtered_2 = grouped_df_filtered.groupby(['keyword']).agg({'ad_id':'count','snippet':'sum'}).reset_index()
for x in grouped_df_filtered_2.itertuples():
    print(x.keyword,x.snippet)
# Out:
# ('ai',) ('AI / AA / AM à 50%\n\nExpert(e) «AI» / AA / AM à 50%\nLausanne\nFaço', "n pour l'assurance-invalidité «AI» et l'assurance-accident AA/AM", "n pour l'assurance-invalidité «AI»/ AA et AM. Vous évaluez des c", "lien avec l'activité d'expert «AI»/AA\n\tBrevet Fédéral en assuran", 'Expert(e) «AI» / AA / AM à 50%\n\nExpert(e) AI', 'ensure registerability of the «AI» in line with the business pla', 'e projects. Plan and initiate «AI» studies deriving from data ca', 'er for the Active Ingredient («AI») Maintenance projects. Plan a', 'tionnaire des prestations AVS-«AI» (100%)\nVos missions\n\tRenseign', 'stionnaire des prestationsAVS-«AI»(100%)\n\nVous avez l’ambition d', ' prestations de l’AVS et de l’«AI»\n\tAnalyser et traiter les dema', 'suivi des dossiers de demande «AI».  Vous participerez aussi à l', 'estations complémentaires AVS/«AI», subside pour l’assurance-mal', 'SEO, le CGPI, le chômage ou l’«AI».\nSi vous souhaitez postuler p', 'ux prestations sociales (AVS, «AI», chômage, etc.).\nVous êtes au', 'AI Planner Trainee\n\n«AI» Planner Trainee - (18035421)\n', ' serve customers everywhere.\n\n«AI» Planner Trainee – 12 months (', '«AI» Planner Trainee\n\nAI Planner T', 'reviewing the sales forecast, «AI» net demands, and then creatin', 'n and interface applicable to «AI» and multiplex assays in Immun', 'gement for a state-of-the-art «AI» product covering cloud-based ', 'of technical delivery for our «AI» Products roadmap ensuring bus', 'ration flows built-in.\n\nDrive «AI» platform evolution; supportin', '\n\nTechnical Delivery Manager («AI» Products)\nremote\nLausanne, Va', 'Technical Delivery Manager («AI» Products)\n\nTechnical Delivery', 'RANGIERBEGLEITER «AI»/AI40 100%\n\nWir suchen Profis ', ' Beziehung.\nDein Profil\n\nIoT, «AI», Big Data, Analytics, Cloud u', ' à contribuer à la communauté «AI» dans le groupe. Vous serez au', 'lated to the potential use of «AI» within the Wealth Management ', 'Master Thesis - Analyst «AI» roadmap\n\nYour team\n\nThe Picte', 'ds\n\nSuggesting priorities for «AI» projects, providing well-stru', 'and conceptualising ideas for «AI» integration aimed at enhancin', 'in-depth research to identify «AI» technology trends and priorit', 'in-depth research to identify «AI» technology directions and pri', 'ernal requirements related to «AI» applications across units wit', 'ding of technology, specially «AI» and its potential future uses', ' concise short-to-medium-term «AI» strategy and roadmap, focusin', 'omputing, data science and/or «AI», are a plus. You should be pr', 'hlägst Du die Brücke zwischen «AI»-Technologien und dem Business', 'a Strategy Consultant\n\nData & «AI»\nAls Data Consultant in Zühlke', 'Dein Spezialgebiet im Bereich «AI» und hilfst, junge Talente zu ', 'tschafterIn unserer Disziplin «AI» in- und extern aktiv und entw', 'r Zusatzausbildung im Bereich «AI» oder über ein erfolgreich abg', 'ls Data Consultant in Zühlkes «AI» + Data Practice schlägst Du d', 'positionieren und damit unser «AI»-Geschäft aktiv noch weiter zu', 'en Dimensionen.\n\nDu verstehst «AI»- und Daten-Technologien als W', 'ge Talente zu entwickeln.\n\nIn «AI»-Projekten und Programmen setz', 'hmerische Vorhaben im Bereich «AI» und Daten und unterstützt uns', 'ersonen bei unseren Kunden in «AI»-Projekten.\n\nDeine Aufgabe:\n\nD', 'und es macht Dir Spass, unser «AI»-Offering zu positionieren und', 'ce Global et les autres sites «AI» pour le partage des bonnes pr', ' existing Active Ingredients («AI»s) through excellence in Produ', 'in relazione ai provvedimenti «AI», soprattutto nella fase di ac', 'apporti richiesti dal mandato «AI»\n\ncurare e mantenere i contatt', 'percorsi relativi alle misure «AI» assegnate agli utenti del CPS', 'erest in new technologies and «AI»\n\nGood knowledge of MS Office ', 'hemen wie Machine\n\n\tLearning, «AI»\n\tErste Erfahrung mit agilen A', 'ain, familiales, maternité et «AI» Établissement, suivi et contr', 'of how digital technology and «AI» is utilized between each othe ...
# ('airflow',) ('der Assessment-Line sowie der «Airflow» Anlage in der Finishing Cell\n',)
# ('algorithm development',) ('l systems and DSP techniques, «algorithm development» and their applications\n\nExper',)
# ('artificial intelligence',) ('l economy on tax competition, «artificial intelligence» and fiscal systems.\n\nThe work', 'lls.\nFamiliar with big data / «artificial intelligence» environments: Azure, Google B', 'edical devices, preferably in «artificial intelligence», cloud computing, radiation e', 'ent, automation, DevOps, J2C, «artificial intelligence» and platforms such as SAP or ', 'ems\n\nSoftware engineering for «artificial intelligence»\n\nLanguages and middleware for', ' (web 3.0, DeFi, big data and «artificial intelligence») disrupting the financial ser', 'nagement, transformation, and «artificial intelligence».\n\nIn addition, you will take ', 'agement, Transformation Risk, «Artificial Intelligence» Risk or similar\n\nSound organi', 'ung, Automatisierung, DevOps, «Artificial Intelligence» und Blockchain adressieren? D', 'Bauen, Internet of Things und «Artificial Intelligence» im Kontext der gebauten Umwel', 'nowledge of data analytics or «artificial intelligence»\n\n\tKnowledge of distributed sy', 'chnologie in Kombination mit ««Artificial Intelligence»» das Fundament des grossen Er', 'et of Things, Data Analytics, «Artificial Intelligence» und Digital Twin sind nicht n', 'Verständnis für Analytics und «Artificial Intelligence» innerhalb des Recruitings bri', 'ctions and adjacent data, and «Artificial Intelligence» and we define, set and manage')
# ('autonomes fahren',) ('y-Wire, Elektromobilität oder «autonomes Fahren». Gemeinsam mit unseren mehr a', 'y-Wire, Elektromobilität oder «autonomes Fahren». Gemeinsam mit über 9.000 Mit', 'y-Wire, Elektromobilität oder «autonomes Fahren». Gemeinsam mit über 9.000 Mit')
# ('autonomous driving',) ('challenges such as Automotive «Autonomous driving» and 5G.\n\nYour role as a RF De',)
# ('bayesian network',) ('nvironmental risk indicators, «Bayesian Network» Models, environmental models,',)
# ('chatbot',) ('chs zu erfassen.\n\nConvertBox («ChatBot»-Funktion oder andere Pop-Up-M', 'chs zu erfassen.\n\nConvertBox («ChatBot»-Funktion oder andere Pop-Up-M')
# ('chatbots',) ('obile development, integrated «chatbots» and cutting edge technology s',)
# ('data mining',) ('ity, Data Science (Big Data / «Data Mining») oder artverwandtem Umfeld\n\tV', 'monstrates strong analytical, «data mining» and reporting skills and can ', 'eiten und Planungsfähigkeit.\n\n«Data Mining»- und Berichtsfähigkeiten über', 'onitoring including trending, «data mining» and reporting.\n\nQuality assur')
# ('deep learning',) ('e clients as a result of your «deep learning» & change knowledge regarding ',)
# ('gan',) ('48V utilisant des transistors «GaN» sur une base de carte d’évalu', '48V utilisant des transistors «GaN»\n\nDans le cadre de cette missi', '48V utilisant des transistors «GaN»\n\tRéalisation de l’étude\n\tSimu', 'ractérisation des transistors «GaN»\n\tTest et validation\n\tProposer')
# ('intelligent automation',) ('«Intelligent Automation» - Technical Consultant (m/f/d', ' German and English speaking ‘«Intelligent Automation» - Technical Consultant’ (m/f/')
# ('jax',) ('nien die korrekten Namen nach «JAX»-Nomenklatur sowie die zugehör',)
# ('ki',) ('-Gruppe des IFIK und weiteren «KI»-Gruppen der Universität sowie', 'den Bereichen soziale Medien, «KI»-basierte Gestaltung und zukun', 't Nutzung neuer Technologien («KI») für neue Business Modelle\n\nE', 'reich Big Data, Data Lake und «KI». Analytische, konzeptionelle ')
# ('llm',) ("e et disposez idéalement d'un «LLM» ou d'une expérience anglo-sax",)
# ('machine learning',) ('n complex data processing and «machine learning» pipelines\n\tCommunicate and co', ' neural data and programming\n\t«Machine learning» approaches and data processin', 'gy, automated image analysis, «machine learning», spectral vegetation indices,', ' phenotyping, image analysis, «machine learning», or proximal sensing, to lead', ', powered by state-of-the-art «machine learning» and probabilistic algorithms.', 'ectronic devices\nKnowledge of «machine learning» tools is a plus\nStrong intere', 'lage statistischer Methoden / «Machine Learning» als Teil agiler interdiszipli', ' Jahre Hands-on Erfahrung mit «Machine Learning» Verfahren und statistischen M', 'with Geospatial modelling and «Machine Learning» would be beneficial\n\tDetail-o', ' such as Tableau, Alteryx and «machine learning».\nYour Skills and Experiences\n', 'ter science (e.g. blockchain, «machine learning») and ethics.\nPosition Availab', 't auseinander.\nDatenanalytik, «Machine Learning» und Monte-Carlo-Simulationen:', 'ntitative skills. Interest in «machine learning» / textual analysis / big data', ' (e.g. multivariate analysis, «machine learning», modelling of behavioral and/', ' of interest, sensor science, «machine learning» and digital medicine.\n\nDevelo', ' of interest, sensor science, «machine learning» and digital medicine.\n\nThis r', 'e the use of data science and «machine learning» techniques broadly within aca', 'nal statistics and inference, «machine learning», statistical mechanics, infor', 'ce, advanced algorithmics and «machine learning» in industrial applications. P', " the area of optimisation and «machine learning» for energy systems.\nWe're imp", 'mathematical optimisation and «machine learning» in projects or internships.\n\n', 'company, we implement and use «Machine Learning». We even invented an intuitiv', 'data processing and deploying «machine learning» models into production\n\nPrefe', 'terest in data management and «machine learning» tooling a plus\n\nInterest in F', 'ives aux data analytics (y c. «machine learning»),\n\nsoutenir l’équipe d’audit ', 'e new tools.\n\nExperience with «machine learning» and/or data engineering.\n\nDes', 'secure and privacy-preserving «machine learning». As a doctoral student you wi', 'pplication of digitalization, «machine learning», analytics, and other Industr', 'gy, automated image analysis, «machine learning», spectral vegetation indices,', ' phenotyping, image analysis, «machine learning», or proximal sensing, to lead', 'nced analytics and innovative «machine learning» techniques. We also support o', 'uvelles technologies comme le «Machine Learning»\n\nBonne connaissance des logic', 'ificiale (Advanced Analytics, «Machine Learning») e dei comuni linguaggi di pr', 'ms für Business Intelligence, «Machine Learning» und Software Entwicklung hols', 'ch auf Business Intelligence, «Machine Learning» und Data Science spezialisier', 'uvelles technologies comme le «Machine Learning»\n\nBonne connaissance des logic', 'nologies (e.g. Blockchain and «Machine Learning») and their application potent', 'nced analytics and innovative «machine learning» techniques. We also support o', 'h data preparation for use in «Machine Learning» algorithms\n\nAdresse\n\nEcoparc ', 'oDB, KNIME, Javascript, basic «Machine Learning» and Statistics knowledge\n\nAbi', 'reiche:\n\nPython Ecosystem for «Machine Learning»\n\nData Modeling für operative ', 'formen und operationalisierst «Machine Learning» Projekte. Du begleitest sie d', 'im Bereich Data Platforms und «Machine Learning» Operations.\n\nDu fühlst dich i', 'ing skills\n\n\t•  Familiar with «Machine Learning» methods applied to finance\n\n\t', ' a professor at EPFL\n\n\t•  Use «machine learning» techniques where appropriate\n', ' will develop statistical and «machine learning» models to derive drought stre', 'ty to the ticketing business («machine learning», other data analysis tools)\n\n', 'd protocols\n\n›Experience with «machine learning» or other data  ...
# ('machine-learning',) ('s.\nApply chemo-informatic and «machine-learning» tools to establish structure-',)
# ('maschinelles lernen',) ('nprodukten (z. B. Modelle für «maschinelles Lernen») in die Kanallandschaft eines', 'che Modelle sowie Modelle für «maschinelles Lernen» für Zeitreihen und Paneldaten')
# ('mistral',) (' compléter l’équipe éducative «MISTRAL», lieu de vie accueillant 5 ré', 'SOCIAL DIPLÔMÉ (H/F) - GROUPE «MISTRAL»\n\nEben-Hézer Lausanne accueill', ' compléter l’équipe éducative «MISTRAL», lieu de vie accueillant 5 ré', 'social diplômé (H/F) - Groupe «Mistral»\nRetour\nEben-Hézer Lausanne ac', 'social diplômé (H/F) - Groupe «Mistral» 80% - 1er février 2022\n\nEduca', 'e Kinderstationen Levante und «Mistral». Der grosszügige Umschwung er')
# ('ml',) ('nd MS Dynamics/Data verse/DLP/«ML»/Automation und mehr\n\nDeine Sk', ' Arbeitszeiten, faire PK, 13. «ML» etc.)\n\nModerne, helle und ger')
# ('mlops',) ('l\n\nPraktische Erfahrungen mit «MLOps» (Deployment, Monitoring, Oper',)
# ('modal',) ('nd can readily switch in a bi-«modal» IT world between taking archi', 'ation favorisant le transfert «modal». En cinq ans, la clientèle de', 'fault\n\n\t, selected\n\nThis is a «modal» window.\n\nBeginning of dialog ', ' of dialog window.\n\nThis is a «modal» window. This modal can be clo', '\nThis is a modal window. This «modal» can be closed by pressing the', 's off\n\n\t, selected\n\nThis is a «modal» window.\n\nBeginning of dialog ', ' of dialog window.\n\nThis is a «modal» window. This modal can be clo', '\nThis is a modal window. This «modal» can be closed by pressing the', 's off\n\n\t, selected\n\nThis is a «modal» window.\n\nBeginning of dialog ', ' of dialog window.\n\nThis is a «modal» window. This modal can be clo', '\nThis is a modal window. This «modal» can be closed by pressing the', 's off\n\n\t, selected\n\nThis is a «modal» window.\n\nBeginning of dialog ')
# ('nlp',) ('expressed experience in using «NLP» to analyse data and provide s', 'vironmental sensors, drones), «NLP» and image analysis. We firmly')
# ('online learning',) (' use of LMS functionality and «online learning» materials on Moodle;\n\tCoach a', 'rt pedagogical approaches for «online learning».\n\nAbout you\n\tBachelor of Scie', 'ntent and delivery methods of «online learning» ;\n\tProficient in MS Office an')
# ('opencv',) ('nssoftware (MATLAB, Simulink, «OpenCV»)\n\nErfahrung im Umgang mit Bil',)
# ('predictive analytics',) ('ysecases\n\nAnsprechpartner für «predictive Analytics» in Koordination mit Analytics', 'nkt (z.B. Business Analytics, «Predictive Analytics», Data Science), Mathematik, S')
# ('predictive maintenance',) ('itz in Neunkirch (SH) eine/n\n\n«Predictive Maintenance» Engineer (m/w/d)\n\nAufgaben\n\nB', 'stemtechnik (FH/ETH) oder CAS «Predictive Maintenance»\n\nSolide Erfahrung im Bereich ', 'Maintenance Engineer (m/w/d)\n\n«Predictive Maintenance» Engineer (m/w/d)\n\nHidrostal A', '«Predictive Maintenance» Engineer (m/w/d)\n\nPredictive ', ' Analysen und Konzepten (z.B. «predictive maintenance»)\n\nSehr gute MS-Office-Kenntni', 'nterstützung in den Bereichen «Predictive Maintenance»\n\n\t•  Mitwirken bei interessan')
# ('predictive modelling',) ('ting, advanced analytics like «predictive modelling», centralized digital services', 'nt group functions to provide «predictive modelling» of patients and site opportun', 'omagnetic near-field and (ii) «predictive modelling» of interactions between physi', ' of the EM nearfield and (ii) «predictive modelling» of interactions between physi')
# ('robotics',) ('nd innovation (e.g. SAP HANA, «robotics»)\n\tFlexible regarding working ', 'on, liquid handlers and other «robotics»\n\n\t•  Basic programming skills', 'ftwareengineering Automation, «Robotics», Controls\nBeringen, Switzerla', 'ftwareengineering Automation, «Robotics», Controls\nBeringen, Switzerla', 'ftwareengineering Automation, «Robotics», Controls\nBeringen, Switzerla', 'ftwareengineering Automation, «Robotics», Controls\nBeringen, Switzerla', 'ftwareengineering Automation, «Robotics», Controls\n\nSYNTEGON\nPraktikum', '-Engineering Automatisierung, «Robotics», I.4.0, Regelungstechnik/Cont', 'ftwareengineering Automation, «Robotics», Controls\nIndustriestrasse 8,', 'Support activities related to «Robotics» automation (RPA) program – pr', ' Anwendungsbereichen des Mako «Robotics» System.\nGewinnen Sie über die', 'E ENG, develop automation and «robotics» road map for all T&W sites\n\nY', 'ying high-end engineering and «robotics» approaches. Particular intere', ' technology\n\nHave passion for «robotics» and solving technical problem', ' in Bioengineering, Medicine, «Robotics», Navigation, and Additive Man', ' imaging systems for surgical «robotics». Within Intuitive Surgical’s ', 'should be as fascinated about «robotics» and automatisation as we are.', ' in future. Our team of young «robotics» and automatisation experts is', ' of Regenerative Medicine and «Robotics», and to promote hybrid techno', 'sign, a good understanding of «robotics» and is highly motivated to cr', 'ssembly\n\nYou will support our «robotics» engineers in solving these ch', 'and you should grow with it.\n\t«Robotics» and automation experts and dr', 'nen und Anlagen (Erfahrung in «Robotics» von Vorteil)\n\nMotivierte Pers', '\nFDN Camps - Coach Technology «Robotics» - 02\n\nEcolint\n\nGenf\n\nbewerten', ' CAMPS COACHES - TECHNOLOGY - «ROBOTICS»\n\nFull-time: the role is 100% ', 'tivities for the Technology - «Robotics» (Lego Mindstorms) camp. Activ', '\nFDN Camps - Coach Technology «Robotics» - 02\n\nLa Grande Boissière/ La', 'he bases of Coding applied to «Robotics» to the students\n\nSu\n\n\tp\n\n\terv', 'FDN Camps - Coach Technology «Robotics» - 02\n\nFDN Camps - Coach Techn', 'omer journeys to analytics to «robotics» solutions.\n\nYou support imple', 'Constructing Designer «Robotics» 80 - 100 %\n\nGetreu der Vision', 'atics, vacuum technology, and «robotics» engineering\n\n\t•  Knowledge of', 'stems consisting of fluidics, «robotics» software, thermal, electrical')
# ('robotik',) ('schinen, Kupplungssysteme und «Robotik». Weltweit ist Stäubli mit meh', 'äte & Werkzeuge\nMechatronik & «Robotik»\nSoftware Engineering & Inform', 'ojektleiter / Projektleiterin «Robotik»\n\nStartseite\n\tEngineering\n\tIde', 'äte & Werkzeuge\nMechatronik & «Robotik»\nSoftware Engineering & Inform', 'ojektleiterin / Projektleiter «Robotik»\n\nTätigkeitsgebiet:\n\nIm Rahmen', ' IoT Zürich\n\tSenior Ingenieur «Robotik» (m/w) Zürich\n\tProjektleiterin', 'g und Ihrem Fachwissen in der «Robotik» können Sie sich bei der Konze', 'ojektleiter / Projektleiterin «Robotik»\n\nHelbling Technik\nProjektleit', 'Fachrichtung Mechatronik oder «Robotik» oder gleichwertige Ausbildung', 'serer Dienstleistungen in der «Robotik» übernehmen Sie die Gesamtvera', 'wir zur Verstärkung des Teams «Robotik» einen qualifizierten\n\nProjekt', 'ojektleiter / Projektleiterin «Robotik»\nOrt: Zürich\nAnstellungsgrad: ', 'äte & Werkzeuge\nMechatronik & «Robotik»\nSoftware Engineering & Inform', 'äte & Werkzeuge\nMechatronik & «Robotik»\nSoftware Engineering & Inform', 'otik Zürich\n\tSenior Ingenieur «Robotik» (m/w) Zürich\n\tProjektleiterin', 'ojektleiter / Projektleiterin «Robotik» Zürich\n\tSenior Ingenieur Robo', 'äte & Werkzeuge\nMechatronik & «Robotik»\nSoftware Engineering & Inform', 'otik Zürich\n\tSenior Ingenieur «Robotik» (m/w) Zürich\n\tProjektleiterin', 'ojektleiter / Projektleiterin «Robotik» Zürich\n\tSenior Ingenieur Robo', 'm Bereich Laborautomation und «Robotik» zuständig.\n\nIhre Tätigkeiten ', 'e #Firmware #Laborautomation #«Robotik» #Codierung #Elektrotechnik #I', 'nupperkurse statt.\n\nWenn dich «Robotik» (Laborautomation) und Technik', 'schinen, Kupplungssysteme und «Robotik». Weltweit ist Stäubli mit meh', 'A Portal) und WinCC, sowie in «Robotik» und Feldbussystemen wie Profi', 'der Entwicklung von komplexen «Robotik» Systemen sowie mechatronische', 'it EPLAN, CNC (SINUMERIK) und «Robotik» (ABB, Fanuc) von Vorteil\n\nGew', 'ntnisse in NC-Programmierung, «Robotik» von Vorteil\n\nKontakt\nPeter Bo', 'Eingriffsmethoden wie z.B die «Robotik», 3D Laparoskopie oder navigie', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'echnik und vorzugsweise erste «Robotik» Kenntnisse\n\nDu zeigst Interes', ' Bau- und Vermessungsgeräten («Robotik» Totalstation)\n\nBranchenübergr', 'er, Wasser oder Elektrizität; «Robotik» und agronomische Methoden, wi', 'siven Operationstechniken und «Robotik»\n\nIndividuelle Karriereplanung', 'erung (Siemens)\n\nErfahrung in «Robotik» und Kameraintegration (Cognex', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'italisierung, Automation oder «Robotik» - alle reden darüber. Bei uns', 'echnik und vorzugsweise erste «Robotik» Kenntnisse\n\nDu zeigst Interes', 'rbeiten ab BIM-Modell und mit «Robotik» Totalstation)\n\nZudem priorisi', 'eutischen Behandlungen (inkl. «Robotik») mit Schwerpunkt neurologisch', 'ilt als Big-Player im Bereich «Robotik» und intelligente Automationsl', ' für die Bereiche Automation, «Robotik» und Fertigung weiter. Mit Ihr', 'n\n\nAnlagenbau, Automation und «Robotik»\n\nJAG realisiert anspruchsvoll', 'pplikationen in den Bereichen «Robotik»/Bildverarbeitung\n\nMithilfe be', 'ahrung mit Automatisation und «Robotik» von Vorteil\n\nGute EDV-Kenntni', 'siven Operationstechniken und «Robotik»\n\nIndividuelle Karriereplanung', 'umsziele suchen wir für unser «Robotik» Team eine initiative, motivie', 'ungs- und Antriebstechnik und «Robotik»\n\nSicherstellung der Verfügbar', 'iven Produkten und modernster «Robotik»  ...
# ('spracherkennung',) (' mit modernstem RIS, PACS und «Spracherkennung».\n\nSie arbeiten in einem abwec', ' mit modernstem RIS, PACS und «Spracherkennung».\nWir erwarten eine offene, fr', ' mit modernstem RIS, PACS und «Spracherkennung».\nWir erwarten eine offene, fr', ' mit modernstem RIS, PACS und «Spracherkennung».\nWir erwarten eine offene, fr', 'vo Siemens)\nGE RIS / PACS mit «Spracherkennung»\n\nTätigkeit in einem Team von ', 'PACS, Digitales Diktieren und «Spracherkennung», automatisiertes Scannen, div')
# ('svm',) ('Beratung Abacus «SVM»/ABEA 80-100 %\n\nAbacus@Abraxas',)
# ('text mining',) ('ues de traitement de données («text mining», classification automatique,\n',)
# ('topic modeling',) ('n (z. B. Kollokationsanalyse, «Topic Modeling», Word Embeddings)\n\nErfahrung ',)
# ('transformers',) ('zed products and services for «transformers» and cellulose-based,\nsustaina',)

# %%
set(grouped_df_filtered.map(lambda x: x[0]))
# Out:
# {'ai',
#  'airflow',
#  'algorithm development',
#  'artificial intelligence',
#  'autonomes fahren',
#  'autonomous driving',
#  'bayesian network',
#  'chatbot',
#  'chatbots',
#  'data mining',
#  'deep learning',
#  'gan',
#  'intelligent automation',
#  'jax',
#  'ki',
#  'llm',
#  'machine learning',
#  'machine-learning',
#  'maschinelles lernen',
#  'mistral',
#  'ml',
#  'mlops',
#  'modal',
#  'nlp',
#  'online learning',
#  'opencv',
#  'predictive analytics',
#  'predictive maintenance',
#  'predictive modelling',
#  'robotics',
#  'robotik',
#  'spracherkennung',
#  'svm',
#  'text mining',
#  'topic modeling',
#  'transformers'}

# %%
# Flatten year → ad → matches into a DataFrame
rows = []
for year, ads in data.items():
    for ad_id, matches in ads.items():
        for m in matches:
            rows.append({
                'year': int(year),
                'ad_id': ad_id,
                'keyword': m.get('keyword'),
                'source': m.get('folder', 'fulltext'),
                'snippet': m.get('text', '')
            })
df = pd.DataFrame(rows)
df.sort_values(by=['year'])
# Out:
#       year                                    ad_id                  keyword  \
# 0     2010  sjmm_suf-1-01-2010-03-05108-0-000000001                  robotik
# 26    2010  sjmm_suf-2-01-2010-03-00680-0-000002102              data mining
# 25    2010  sjmm_suf-2-01-2010-03-01270-0-000001790  algorithmus-entwicklung
# 24    2010  sjmm_suf-2-01-2010-03-01270-0-000001774              text mining
# 23    2010  sjmm_suf-2-01-2010-03-00354-0-000001384     intelligente systeme
# ...    ...                                      ...                      ...
# 1327  2024  sjmm_suf-2-05-2024-03-05721-1-000366992                       ai
# 1326  2024  sjmm_suf-2-05-2024-03-05710-1-000349856                     llms
# 1325  2024  sjmm_suf-2-05-2024-03-05710-1-000349856                      llm
# 1343  2024  sjmm_suf-2-05-2024-03-05721-1-000366992                langchain
# 1548  2024  sjmm_suf-2-05-2024-03-06486-1-000368457   predictive maintenance
#
#         source                                            snippet
# 0     fulltext  le Zahnräder und Getriebe für die Medizin und ...
# 26    fulltext   collections processes,- Knowledge of statisti...
# 25    fulltext  dungen gemacht.\nIdealerweise haben Sie bereit...
# 24    fulltext  klungsprojekten in den Bereichen Data-Warehous...
# 23    fulltext  iesen.\nBasierend auf modernsten Komponenten r...
# ...        ...                                                ...
# 1327  fulltext  usses on solving complex business problems usi...
# 1326  fulltext  emonstrate how generative artificial intellige...
# 1325  fulltext  emonstrate how generative artificial intellige...
# 1343  fulltext  XA GenAI Community and work with technology co...
# 1548  fulltext  rfahrung in der Erstellung von Analysen und Ko...
#
# [1549 rows x 5 columns]

# %%
for x in df.query("keyword == 'ner'").itertuples():
    print(x.year, x.snippet)

# %%
# Overview
total_ads = df['ad_id'].nunique()
total_mentions = len(df)
unique_keywords = df['keyword'].nunique()
print(f'Ads with ≥1 match: {total_ads:,}')
print(f'Total keyword mentions: {total_mentions:,}')
print(f'Unique keywords matched: {unique_keywords}')
print(df['keyword'].value_counts())
# Out:
# Ads with ≥1 match: 615
# Total keyword mentions: 1,549
# Unique keywords matched: 104
# keyword
# ai                         319
# machine learning           252
# robotics                   127
# robotik                    112
# ml                          64
#                           ...
# bayesian network             1
# autonomous driving           1
# collaborative filtering      1
# genetic algorithm            1
# question answering           1
# Name: count, Length: 104, dtype: int64

# %%
# Mentions per year
per_year = df.groupby('year').size().rename('mentions').reset_index()
ax = per_year.plot(x='year', y='mentions', figsize=(10,4), title='AI mentions per year (full text)')
ax.set_xlabel('Year'); ax.set_ylabel('Mentions'); plt.show()
per_year
# Out:
#     year  mentions
# 0   2010        27
# 1   2011        31
# 2   2012        42
# 3   2013        30
# 4   2014        21
# 5   2015        55
# 6   2016        35
# 7   2017        97
# 8   2018       100
# 9   2019       155
# 10  2020       181
# 11  2021       156
# 12  2022       175
# 13  2023       120
# 14  2024       324

# %%
# Top keywords overall
top_kw = df['keyword'].value_counts().head(30)
print(top_kw)
if sns is not None:
    plt.figure(figsize=(8,8))
    sns.barplot(x=top_kw.values, y=top_kw.index, orient='h')
    plt.title('Top 30 keywords (full text)'); plt.xlabel('Mentions'); plt.ylabel('Keyword')
    plt.show()
# Out:
# keyword
# ai                             195
# machine learning               166
# robotik                         57
# robotics                        55
# ml                              51
# artificial intelligence         46
# deep learning                   27
# generative ai                   24
# künstliche intelligenz          22
# kuenstliche intelligenz         22
# natural language processing     21
# nlp                             14
# modal                           13
# llm                             12
# tensorflow                      12
# computer vision                 12
# data mining                     12
# ki                              11
# genai                            9
# predictive maintenance           8
# keras                            8
# maschinelles lernen              7
# pytorch                          7
# spracherkennung                  6
# ml models                        6
# mistral                          6
# neural networks                  6
# opencv                           5
# intelligent automation           5
# llms                             4
# Name: count, dtype: int64

# %%
# Sample snippets for manual QA
sample = df.sample(min(10, len(df)), random_state=42) if len(df) else df
sample[['year','ad_id','keyword','snippet']].head(10)
# Out:
#       year                                    ad_id              keyword  \
# 950   2022  sjmm_suf-2-05-2022-03-05898-1-000087083                   ml
# 168   2019  sjmm_suf-2-02-2019-03-01781-0-000000627             robotics
# 220   2019  sjmm_suf-2-02-2019-03-02462-0-000001997     machine learning
# 1179  2023  sjmm_suf-2-05-2023-03-05354-1-000256902                   ki
# 344   2019  sjmm_suf-3-01-2019-03-09018-1-024007738                  nlp
# 271   2019  sjmm_suf-2-02-2019-03-02713-0-000003342             robotics
# 1210  2023  sjmm_suf-2-05-2023-03-05898-1-000261966       language model
# 1245  2023  sjmm_suf-3-01-2023-03-09010-1-044819352                   ml
# 1607  2024  sjmm_suf-2-05-2024-03-05898-1-000356217                   ai
# 1336  2024  sjmm_suf-3-01-2024-03-09003-1-055816169  maschinelles lernen
#
#                                                 snippet
# 950   e development and safe use of «ML» applied to ...
# 168   pplikation Operations Manager «Robotics» Platt...
# 220   Modelling, Anomaly Detection, «Machine Learnin...
# 1179  r Strassenbau (w/m) 100%\n\nDie «KI»BAG ist ei...
# 344   ng und Entwicklung im Bereich «NLP»\nProjektma...
# 271   unting and Billing\n\n\t•  Cloud «Robotics»: C...
# 1210  systems, link prediction, NLP «language model»...
# 1245  poste de\n\nProfesseur·e HES en «ML» engineeri...
# 1607  om, integration of generative «AI», interactiv...
# 1336  che Modelle sowie Modelle für «maschinelles Le...
